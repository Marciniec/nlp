# %%
from elasticsearch import Elasticsearch
from os import listdir
from os.path import isfile, join

# %%
client = Elasticsearch([
    {'host': 'localhost'},
])

# %%
create_index_body = {
      'settings': {
        'number_of_shards': 1,
        'number_of_replicas': 0,

        'analysis': {
          'analyzer': {
            'bill_analyzer': {
              'type': 'custom',
              'tokenizer': 'standard',
              'filter': ['morfologik_stem', 'lowercase', "filter_shingle"]
            }
          },
        "filter": {
         "filter_shingle": {
          "type": "shingle",
          "max_shingle_size": 2,
          "min_shingle_size": 2,
          "output_unigrams": False
        }
      }
        }
      },
      'mappings': {
        'bill': {
          'properties': {
            'content': {'type': 'text', 'analyzer': 'bill_analyzer'},
          }
        }
      }
    }

# %%
client.indices.create(    
    index='bill_index2',
     body=create_index_body)
# Out:
# PUT http://localhost:9200/bill_index2 [status:400 request:0.030s]
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# <ipython-input-7-bbdbc714497e> in <module>
#       1 client.indices.create(
#       2     index='bill_index2',
# ----> 3      body=create_index_body)
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#      74                 if p in kwargs:
#      75                     params[p] = kwargs.pop(p)
# ---> 76             return func(*args, params=params, **kwargs)
#      77         return _wrapped
#      78     return _wrapper
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/client/indices.py in create(self, index, body, params)
#      86             raise ValueError("Empty value passed for a required argument 'index'.")
#      87         return self.transport.perform_request('PUT', _make_path(index),
# ---> 88             params=params, body=body)
#      89
#      90     @query_params('allow_no_indices', 'expand_wildcards', 'flat_settings',
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     316                 delay = 2**attempt - 1
#     317                 time.sleep(delay)
# --> 318                 status, headers_response, data = connection.perform_request(method, url, params, body, headers=headers, ignore=ignore, timeout=timeout)
#     319
#     320             except TransportError as e:
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     184         if not (200 <= response.status < 300) and response.status not in ignore:
#     185             self.log_request_fail(method, full_url, url, body, duration, response.status, raw_data)
# --> 186             self._raise_error(response.status, raw_data)
#     187
#     188         self.log_request_success(method, full_url, url, body, response.status,
#
# /usr/local/lib/python3.6/dist-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     123             logger.warning('Undecodable raw error response from server: %s', err)
#     124
# --> 125         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(status_code, error_message, additional_info)
#     126
#     127
#
# RequestError: RequestError(400, 'resource_already_exists_exception', 'index [bill_index2/FSlXsBzUQ1WgtWtmGI1KXQ] already exists')

# %%
def load_data(directory_path):
    files = [file for file in listdir(directory_path) if isfile(join(directory_path, file))]
    for file in files:
        with open(f"{directory_path}/{file}") as input_file:
            client.index(index='bill_index2', id=f"{file}", doc_type='bill', body={'content':input_file.read() })

# %%
load_data('./data/')

# %%
def get_ids(directory_path):
    files = [file for file in listdir(directory_path) if isfile(join(directory_path, file))]
    ids = map(lambda file: f"{file}",files)
    return list(ids)

# %%
ids = get_ids('./data/')

# %%
global_frequency = {}

# %%
def get_global_term_frequency(terms_data):
    for term in terms_data:
        if term not in global_frequency:
            global_frequency[term] = terms_data[term]['ttf']

# %%
def get_terms_data(term_vectors):
    return term_vectors['term_vectors']['content']['terms']

# %%
def get_terms(terms_data):
    return terms_data.keys()

# %%
for id_ in ids:
    term_vectors = client.termvectors(index='bill_index2', doc_type='bill', id=id_, body= {
      "fields" : ["content"],
      "offsets" : True,
      "payloads" : True,
      "positions" : True,
      "term_statistics" : True,
      "field_statistics" : True
    })
    term_data = get_terms_data(term_vectors)
    get_global_term_frequency(term_data)

# %%
global_frequency = deserialize('bigram_freq.pickle')

# %%
filtered_bigrams = {}

# %%
for key in global_frequency:
    if len(key.split(' ')) > 2:
        continue
    first, second = key.split(' ')[:2]
    if first.isalpha() and second.isalpha():
        filtered_bigrams[key] = global_frequency[key]

# %%
import pickle
with open('global_frequency.pickle', 'rb') as handle:
    unigram_frequency =  pickle.load(handle)

# %%
sorted_bigrams = sorted(filtered_bigrams.items(), key=lambda entry: entry[1] , reverse=True)

# %%
sorted_bigrams[:30]
# Out:
# [('w wiek', 188282),
#  ('o ocean', 65201),
#  ('ocean ojciec', 65201),
#  ('lub lubić', 46100),
#  ('wiek artykuł', 32202),
#  ('ojciec który', 28762),
#  ('który mowa', 28644),
#  ('mowa w', 28576),
#  ('wiek usta', 23585),
#  ('nie on', 23070),
#  ('brzmienie brzmieć', 17975),
#  ('rok numer', 17943),
#  ('od oda', 16124),
#  ('określić w', 13934),
#  ('określony określić', 13471),
#  ('może móc', 12148),
#  ('z dzień', 11416),
#  ('ten to', 10642),
#  ('otrzymywać brzmienie', 10587),
#  ('sprawa sprawić', 10037),
#  ('prawo prawy', 9651),
#  ('ustawa z', 8811),
#  ('albo alba', 8760),
#  ('do sprawa', 8737),
#  ('i numer', 8634),
#  ('właściwy do', 8563),
#  ('postępowanie postępować', 8549),
#  ('dodawać się', 8235),
#  ('minister właściwy', 7958),
#  ('wiek brzmienie', 7329)]

# %%
serialize('bigram_freq')

# %%
import math
def pmi(bigram):
    try:
        word1, word2 = bigram.split(' ')[:2]
        prob_word1 = unigram_frequency[word1] / float(sum(unigram_frequency.values()))
        prob_word2 = unigram_frequency[word1] / float(sum(unigram_frequency.values()))
        prob_word1_word2 = filtered_bigrams[bigram] / float(sum(filtered_bigrams.values()))

        return math.log(prob_word1_word2/float(prob_word1*prob_word2),2)
    except: # Occurs when calculating PMI for Out-of-Vocab words.
        return 0

# %%
pmi_dict = {}

# %%
for bigram in filtered_bigrams:
    pmi_dict[bigram] = pmi(bigram)

# %%
import pickle
def serialize(name, dictionary):
    with open(name, 'wb') as handle:
        pickle.dump(dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def deserialize(name):
    with open(name, 'rb') as handle:
        return pickle.load(handle)

# %%
serialize('pmi_dict.pickle', pmi_dict)

# %%
sorted_pmi = sorted(pmi_dict.items(), key=lambda entry: entry[1] , reverse=True)

# %%
sorted_pmi[:30]
# Out:
# [('całodobowo całodobowy', 22.61321701827587),
#  ('swłaściwym minister', 22.61321701827587),
#  ('głuchowo pogórska', 22.61321701827587),
#  ('głuchów głuch', 22.61321701827587),
#  ('karczewska wraz', 22.61321701827587),
#  ('komorowice oświęcim', 22.61321701827587),
#  ('kotowo zielona', 22.61321701827587),
#  ('kozienice radom', 22.61321701827587),
#  ('mop nie', 22.61321701827587),
#  ('mory wola', 22.61321701827587),
#  ('mpa łączyć', 22.61321701827587),
#  ('polkowice żary', 22.61321701827587),
#  ('płońsk olsztyn', 22.61321701827587),
#  ('rozwadów strachocina', 22.61321701827587),
#  ('skocz komorowice', 22.61321701827587),
#  ('skoczów skocz', 22.61321701827587),
#  ('tłocznia tłoczny', 22.61321701827587),
#  ('tłoczny gaz', 22.61321701827587),
#  ('wycinek drzewo', 22.61321701827587),
#  ('wycinka wycinek', 22.61321701827587),
#  ('dodatnio dodatni', 22.61321701827587),
#  ('funkcjonariuszakobiety w', 22.61321701827587),
#  ('generalski mianować', 22.61321701827587),
#  ('ofiarnia i', 22.61321701827587),
#  ('ofiarnie ofiarnia', 22.61321701827587),
#  ('powitanie i', 22.61321701827587),
#  ('pożegnanie podczas', 22.61321701827587),
#  ('pełnozatrudniony który', 22.61321701827587),
#  ('predestynować do', 22.61321701827587),
#  ('bierczy który', 22.61321701827587)]

# %%
from collections import Counter
from llr import llr_2x2

# %%
llr_dict = {}
for bigram in filtered_bigrams:
    word1, word2 = bigram.split(' ')
    not_word1_word2 = unigram_frequency[word2] - filtered_bigrams[bigram] 
    word1_not_word2 = unigram_frequency[word1] - filtered_bigrams[bigram]
    not_word1_not_word2 = sum(filtered_bigrams.values()) - word1_not_word2 - not_word1_word2 - filtered_bigrams[bigram]
    llr_dict[bigram] = llr_2x2(filtered_bigrams[bigram],not_word1_word2, word1_not_word2, not_word1_not_word2 )

# %%
sorted_llr = sorted(llr_dict.items(), key=lambda entry: entry[1] , reverse=True)

# %%
sorted_llr[0:30]
# Out:
# [('w wiek', 1512868.9505226118),
#  ('o ocean', 672851.4528762214),
#  ('ocean ojciec', 672005.4768584454),
#  ('lub lubić', 507926.1540169112),
#  ('który mowa', 272440.30304606585),
#  ('brzmienie brzmieć', 231986.2291352484),
#  ('nie on', 218071.38664999907),
#  ('od oda', 206144.70497495937),
#  ('ojciec który', 187554.41064130655),
#  ('mowa w', 177773.8951709359),
#  ('określony określić', 158198.62992483506),
#  ('może móc', 146529.94176982663),
#  ('wiek artykuł', 134558.28035960603),
#  ('prawo prawy', 129713.60182514365),
#  ('albo alba', 125689.02884591662),
#  ('postępowanie postępować', 120219.07562063898),
#  ('sprawa sprawić', 118927.15771334711),
#  ('otrzymywać brzmienie', 117826.99283330375),
#  ('rok numer', 111763.4088798624),
#  ('bar bardzo', 101144.60221865875),
#  ('bardzo bieżący', 98160.79109145659),
#  ('niż niża', 96873.13036181423),
#  ('niża nizać', 96873.13036181423),
#  ('ten to', 95596.42725932016),
#  ('środki środek', 94425.78330453657),
#  ('rozporządzenie rozporządzić', 93733.6981369172),
#  ('bieżący były', 92705.37888645337),
#  ('warunki warunek', 87200.41297277952),
#  ('wiek usta', 78198.46011369722),
#  ('minister właściwy', 74541.00805232773)]

# %%
sorted_llr[:30]
# Out:
# [('w wiek', 1512868.9505226118),
#  ('o ocean', 672851.4528762214),
#  ('ocean ojciec', 672005.4768584454),
#  ('lub lubić', 507926.1540169112),
#  ('który mowa', 272440.30304606585),
#  ('brzmienie brzmieć', 231986.2291352484),
#  ('nie on', 218071.38664999907),
#  ('od oda', 206144.70497495937),
#  ('ojciec który', 187554.41064130655),
#  ('mowa w', 177773.8951709359),
#  ('określony określić', 158198.62992483506),
#  ('może móc', 146529.94176982663),
#  ('wiek artykuł', 134558.28035960603),
#  ('prawo prawy', 129713.60182514365),
#  ('albo alba', 125689.02884591662),
#  ('postępowanie postępować', 120219.07562063898),
#  ('sprawa sprawić', 118927.15771334711),
#  ('otrzymywać brzmienie', 117826.99283330375),
#  ('rok numer', 111763.4088798624),
#  ('bar bardzo', 101144.60221865875),
#  ('bardzo bieżący', 98160.79109145659),
#  ('niż niża', 96873.13036181423),
#  ('niża nizać', 96873.13036181423),
#  ('ten to', 95596.42725932016),
#  ('środki środek', 94425.78330453657),
#  ('rozporządzenie rozporządzić', 93733.6981369172),
#  ('bieżący były', 92705.37888645337),
#  ('warunki warunek', 87200.41297277952),
#  ('wiek usta', 78198.46011369722),
#  ('minister właściwy', 74541.00805232773)]

# %%
list(filter(lambda x:x[1]< 30  ,sorted_llr))
# Out:
# [('vina ostatnie', 29.9996449445116),
#  ('dania republika', 29.99907760869064),
#  ('niderlandy republika', 29.99907760869064),
#  ('osad ściekowy', 29.997605890222076),
#  ('indywidualny rozkład', 29.997251689466793),
#  ('uprawny przed', 29.99593668903981),
#  ('zataić bezprawny', 29.99593288399592),
#  ('treść polecenie', 29.99587682002675),
#  ('przebieg linia', 29.995519822890856),
#  ('rezerwowy przeznaczyć', 29.994813740857353),
#  ('przeciwnik skarga', 29.994722044228183),
#  ('dyscyplinarny polegać', 29.994699481947464),
#  ('podatnik dokonać', 29.994343852682505),
#  ('wczesno mieć', 29.993120791361434),
#  ('socjalna mieszkanie', 29.992278000016086),
#  ('wskaźnik charakteryzować', 29.99085549197116),
#  ('mój pozycja', 29.9907835269114),
#  ('ramy przedpłata', 29.98984542638209),
#  ('przekazać dotacja', 29.98916874139104),
#  ('dochód rok', 29.985382656974252),
#  ('ziemski zastępować', 29.984251514004427),
#  ('sprawa zakład', 29.983786597964354),
#  ('według wynalazek', 29.98367067588697),
#  ('frd odbywać', 29.983105238548887),
#  ('warunek spełnienie', 29.981370822206372),
#  ('ureaform u', 29.981350885624124),
#  ('miligram dwutlenek', 29.981268993534286),
#  ('przed utrata', 29.9810906239436),
#  ('fundusz obciążać', 29.977897114760708),
#  ('jeżeli żądanie', 29.97689442546107),
#  ('budowlany w', 29.97676757327281),
#  ('być kierować', 29.976694854092784),
#  ('organizacyjny posiadający', 29.974643484456465),
#  ('pidżama z', 29.97440328716766),
#  ('pętelkowy z', 29.97440328716766),
#  ('okrągły z', 29.97440328716766),
#  ('praca a', 29.971759989392012),
#  ('kolejność otrzymać', 29.97140826303803),
#  ('ten zawrzeć', 29.970572583028115),
#  ('planować rozmieszczenie', 29.969598019986734),
#  ('wiek poziom', 29.969214930431917),
#  ('on wadliwość', 29.968827995820902),
#  ('dzień wojewódzki', 29.968446839950047),
#  ('kary który', 29.967771358322352),
#  ('koszt punkt', 29.967554612725507),
#  ('przed podrobić', 29.966425955557497),
#  ('istotny wątpliwość', 29.96445636415956),
#  ('podmiot wat', 29.962377899792045),
#  ('obszar występowanie', 29.961975467580487),
#  ('okres umowy', 29.961019814305473),
#  ('się bezpośredni', 29.960755545762368),
#  ('łączny obniżka', 29.960632296395488),
#  ('rodzic przysposobiony', 29.95792832016741),
#  ('pracownik dotychczasowy', 29.956420614777016),
#  ('podczas przewóz', 29.95632106782068),
#  ('ramy reklamy', 29.954858476161462),
#  ('konieczność prowadzenie', 29.95233721593104),
#  ('również pełnoletni', 29.951863858783327),
#  ('likwidować ognisko', 29.951535966333722),
#  ('wybierać wiceprzewodniczący', 29.951519041762367),
#  ('przedłużyć kontrola', 29.95149228684022),
#  ('wiarygodny wiadomość', 29.951120854644614),
#  ('mój pierwszeństwo', 29.950584715385048),
#  ('odnowić uniwersytet', 29.94901667415388),
#  ('młody dyspozytor', 29.944984000031127),
#  ('nieodpłatnie dane', 29.94427953880222),
#  ('statek inspekcyjny', 29.944128216222452),
#  ('kontrola albo', 29.942290622217115),
#  ('niedbalstwo ubezpieczać', 29.94190173262905),
#  ('program owoc', 29.941766207695764),
#  ('stały piecza', 29.941257923208468),
#  ('ustawa warunki', 29.940427082998212),
#  ('propozycja niezbędny', 29.93914714982384),
#  ('cielesny podlegać', 29.939042403319036),
#  ('kilogram sacharoza', 29.938272478401814),
#  ('wyrządzić zanieczyszczenie', 29.9380631392778),
#  ('zostać postawić', 29.937987865981995),
#  ('odzyskiwać ten', 29.937582559941802),
#  ('wielkość i', 29.93688579276204),
#  ('wytrzymałościowy wykonanie', 29.936269233730854),
#  ('zbędny cierpienie', 29.93544435509739),
#  ('uprawnienie określony', 29.932461722986773),
#  ('pokrzywdzić odpowiedzieć', 29.931448869469932),
#  ('kurs zawodowy', 29.930520564084873),
#  ('pobyt nieletni', 29.93045706221892),
#  ('program z', 29.929513465845957),
#  ('specjalny integracyjny', 29.929195468597754),
#  ('u użytkownik', 29.92850594814081),
#  ('udostępnić prospekt', 29.92772947198864),
#  ('wobec aplikant', 29.927323506857647),
#  ('bezpieczeństwo przewóz', 29.925102559798688),
#  ('krótkotrwały zakwaterowanie', 29.923784413055728),
#  ('szeregowy mianować', 29.92316182254399),
#  ('wartość punkt', 29.922640126897022),
#  ('odzwierzęcy czynnik', 29.92183361364914),
#  ('zachowywać ostrożność', 29.92084071008685),
#  ('trwać związek', 29.9202610343782),
#  ('zwrotny roszczenie', 29.919980435815887),
#  ('porządek i', 29.919153181253932),
#  ('przybyć przybycie', 29.9191242911088),
#  ('chorąża sztabowy', 29.9191242911088),
#  ('udostępnić wyłącznie', 29.91818254924874),
#  ('skutkować przyznanie', 29.916906138501872),
#  ('forma przymiotnikowy', 29.916033101675566),
#  ('lekarski lub', 29.915856699517462),
#  ('ustalać arta', 29.91551914543379),
#  ('staż nauczyciel', 29.91383315920757),
#  ('doprowadzać do', 29.91370443359483),
#  ('gromadzić zbiory', 29.912605315836117),
#  ('określać porozumienie', 29.911337046301924),
#  ('stopień uciążliwość', 29.911011226839037),
#  ('były praca', 29.909953857946675),
#  ('postępować właściwy', 29.90964357473422),
#  ('wdraa postanowienie', 29.909310410628677),
#  ('jadalny tłuszcz', 29.90853771704724),
#  ('ustalać okres', 29.90819766971981),
#  ('żyć przez', 29.90747325477423),
#  ('rachunek lokat', 29.906461415019294),
#  ('lubić kontynuować', 29.9052790547139),
#  ('przewozowy lub', 29.9052790547139),
#  ('kraj numer', 29.905142836738378),
#  ('systema kanalizacyjny', 29.90468727586631),
#  ('umowa lub', 29.90462384640705),
#  ('typ dom', 29.90428960259669),
#  ('koło metr', 29.903438666122383),
#  ('z skazać', 29.902368284063414),
#  ('to prawo', 29.901575836120173),
#  ('nabyć podczas', 29.901016625080956),
#  ('droga inny', 29.898298549000174),
#  ('przez pośredniczyć', 29.89723501628032),
#  ('inny rozporządzenie', 29.896835647406988),
#  ('charytatywny nadwyżka', 29.896657223667717),
#  ('z zbywca', 29.896223627380095),
#  ('zaistnieć potrzeba', 29.89578259976406),
#  ('diagnostyka mikrobiologiczny', 29.894944916422446),
#  ('udzielać ubezpieczony', 29.894917206031096),
#  ('wczesny przekazywać', 29.893701706067077),
#  ('ogłaszać corocznie', 29.892785567226383),
#  ('jednorazowy wartość', 29.892666449057288),
#  ('przyłączyć podmiot', 29.892595189157873),
#  ('uzasadniać nadanie', 29.890946659208566),
#  ('przypadek awaria', 29.89050609516562),
#  ('norma iso', 29.890315642678615),
#  ('prawo działalność', 29.89026599418139),
#  ('uprzedni trzymiesięczny', 29.88986975527405),
#  ('dziecko nie', 29.88852987071732),
#  ('zakres sprawozdawczość', 29.888093309331452),
#  ('brzmieć czynności', 29.8874083677656),
#  ('wartość transakcja', 29.88553190015955),
#  ('wywłaszczeniowy wszczynać', 29.885476128179107),
#  ('oraz kara', 29.8854565982474),
#  ('gospodarka niezwłocznie', 29.883880982219125),
#  ('wydać od', 29.883228703285567),
#  ('poszczególny pytanie', 29.882320864362555),
#  ('nakazać poddanie', 29.881944285131794),
#  ('siedliskowy las', 29.881901715196364),
#  ('wyprawa bez', 29.880864357270184),
#  ('integralność ciało', 29.879240136768203),
#  ('rolny arta', 29.87836141261505),
#  ('wyraźny widoczny', 29.87822534263296),
#  ('on posiadacz', 29.87780253798701),
#  ('podatnik wykorzystywać', 29.876595713467395),
#  ('maj każdy', 29.875755976798246),
#  ('wykazać naruszenie', 29.874539243493928),
#  ('kwadrat pan', 29.87379261197475),
#  ('hurtowy bar', 29.87360899784835),
#  ('powiązać bar', 29.87360899784835),
#  ('karo lub', 29.8734230423579),
#  ('obowiązek przepis', 29.873415402835235),
#  ('przekazać obwodowy', 29.873264665948227),
#  ('ustawa prawa', 29.871037176053505),
#  ('obowiązek pobranie', 29.87086831755005),
#  ('który zamawiać', 29.86769804963842),
#  ('odwoławczy rozdział', 29.867039520366234),
#  ('spełnić określony', 29.866362897271756),
#  ('liczba stawek', 29.865796206780942),
#  ('litosfera złożony', 29.86563472803391),
#  ('obiekt chronić', 29.865300910911174),
#  ('członek regionalny', 29.862011855409946),
#  ('naprawa odzież', 29.861822576645864),
#  ('tworzyć niepowtarzalny', 29.861731789940677),
#  ('podwładny wspólnie', 29.861644209980113),
#  ('określić przed', 29.861135335813742),
#  ('dziedzina przemysł', 29.861026080077863),
#  ('wysokość nadwyżka', 29.860727487524855),
#  ('pomniejszy jeść', 29.86002793399166),
#  ('powinien dodatkowo', 29.85985140036064),
#  ('pełnomocnictwo powinien', 29.85985140036064),
#  ('pobliże miejsce', 29.859572007437237),
#  ('do wodny', 29.8588928404497),
#  ('móc umorzyć', 29.858623953041388),
#  ('chrześcijański misja', 29.858283674655468),
#  ('dumpingowy wyrządzać', 29.85778655887316),
#  ('jeżeli zgodnie', 29.855131765129045),
#  ('osoba decyzja', 29.85457451059483),
#  ('koszty wyżywienie', 29.852646756058675),
#  ('być nieprawdziwy', 29.849639057938475),
#  ('kryterium klasyfikacja', 29.849431136150088),
#  ('wyhodować wyprodukować', 29.849029164978674),
#  ('przewodniczyć powoływać', 29.84882145568554),
#  ('pierwokup nieruchomość', 29.848691631224938),
#  ('rok swój', 29.848607233725488),
#  ('choroba niebieski', 29.84841377603516),
#  ('który dokument', 29.847681604442187),
#  ('dzień jeżeli', 29.84727805358125),
#  ('instrukcja szkoleniowy', 29.846442693609788),
#  ('karo przewidzieć', 29.84613425110001),
#  ('on system', 29.8460416655289),
#  ('otrzymać oferta', 29.846023466459883),
#  ('zakończyć produkcja', 29.845041717890126),
#  ('uzupełnić dowód', 29.84209752615061),
#  ('polecić testamentowy', 29.841319172391195),
#  ('oda ogień', 29.83973267924739),
#  ('mineralny bitumiczny', 29.839147382735973),
#  ('świadczeniobiorca bezdomny', 29.837595499158397),
#  ('zalesić hektar', 29.83531910113743),
#  ('utracić zarobek', 29.835260044741517),
#  ('inny maszyna', 29.833696792193223),
#  ('prowadzić współpraca', 29.833494761609472),
#  ('korzystać i', 29.833207623800263),
#  ('połączyć lub', 29.833055544411764),
#  ('wstrzymać jej', 29.831735716375988),
#  ('zawiadomić frachtować', 29.831711945444113),
#  ('sąd zobowiązywać', 29.831658756229444),
#  ('napotykać przeszkoda', 29.831594831849543),
#  ('i monitorować', 29.83109267312102),
#  ('atmosferyczny okres', 29.830692743853433),
#  ('chorobowy stanowić', 29.83021287912561),
#  ('akcyjny powinien', 29.8297254841018),
#  ('wiek umowa', 29.829014593735337),
#  ('procedura kontrola', 29.828440681332722),
#  ('skupywać ryba', 29.828340251627196),
#  ('miesiąc oda', 29.82820251962403),
#  ('skutek jak', 29.826505256802193),
#  ('inny działanie', 29.826075597200543),
#  ('ograniczać dostęp', 29.82451397722616),
#  ('konosament wystawić', 29.824397839704034),
#  ('depozytowy wystawić', 29.824397839704034),
#  ('grozić ujawnienie', 29.824210789502104),
#  ('rów pas', 29.823782958787888),
#  ('realizacja usługa', 29.82333514621132),
#  ('skazić środki', 29.821894828171935),
#  ('myśliwski wraz', 29.821481470378785),
#  ('uprościć tryb', 29.82147464659647),
#  ('karta opis', 29.81983575409322),
#  ('lubić funkcja', 29.819755931268446),
#  ('górski ochotniczy', 29.818045100751533),
#  ('dystrybucja ciepło', 29.815569659162975),
#  ('warunek przyznanie', 29.81519891503558),
#  ('obowiązywać na', 29.81243437610101),
#  ('zainstalować elektryczny', 29.80947907060181),
#  ('zadanie w', 29.809271248057485),
#  ('dokonywać nagranie', 29.80910037576541),
#  ('pokryć wierzytelność', 29.80858475233981),
#  ('kwalifikacyjny wobec', 29.808575453833328),
#  ('wieloletni umówić', 29.80835971302804),
#  ('portugalski ustanawiać', 29.808037494577547),
#  ('gotowość przystąpienie', 29.807529052568498),
#  ('tajemnica spowiedź', 29.80710938306038),
#  ('podobny element', 29.805722510483974),
#  ('amonowy cytrynian', 29.804253222451734),
#  ('przemieścić na', 29.803744485019706),
#  ('sporządzić miejscowe', 29.803664282298996),
#  ('odpady arta', 29.80257654149318),
#  ('organ wieloosobowy', 29.80092553558643),
#  ('dyscyplinarny przejmować', 29.800873915213742),
#  ('zastaw lub', 29.80053254874656),
#  ('dostarczyć organowy', 29.80003740878601),
#  ('z szkoda', 29.799943368998356),
#  ('dochodowy na', 29.79869288369082),
#  ('raz pasywa', 29.79837686802057),
#  ('przedmiot symbolizować', 29.798353176134697),
#  ('moc o', 29.797500380896963),
#  ('rybacki wyłowić', 29.797004877138534),
#  ('usługa prawniczy', 29.796458187258395),
#  ('wymierzyć administracyjny', 29.79523789879022),
#  ('kablowy wolno', 29.793440193553124),
#  ('zapewnić jawność', 29.793084533052024),
#  ('agencyjny mniej', 29.792854500403337),
#  ('rozrachunkowy pełnia', 29.792854500403337),
#  ('wieloletni budowo', 29.791761826608763),
#  ('atest jakościowy', 29.791601766094573),
#  ('zezwolić starosta', 29.789060649229214),
#  ('komisja sprawa', 29.788926648092456),
#  ('i przysposobiony', 29.786985630518757),
#  ('kwalifikacja z', 29.78670253197197),
#  ('także przyjęcie', 29.78630311966117),
#  ('instalacja nie', 29.785307216690853),
#  ('oraz wyznaczać', 29.785056535736658),
#  ('wypłata kwota', 29.784280176041648),
#  ('droga kupno', 29.783814267240814),
#  ('związać oraz', 29.78370648017153),
#  ('składka związkowy', 29.782421279851405),
#  ('funkcjonalność baza', 29.782112423010403),
#  ('raz zwłoki', 29.781336738582468),
#  ('niedostateczność opakowanie', 29.78101192620852),
#  ('wyłącznie nadmierny', 29.780036897875107),
#  ('oraz dotyczyć', 29.78001034987392),
#  ('tryba uzyskiwać', 29.779073002704536),
#  ('organ rad', 29.779063597437926),
#  ('statut regionalny', 29.779055161307042),
#  ('wniosek ubezpieczony', 29.778948415856576),
#  ('przypisać im', 29.778746877978847),
#  ('prowadzić polityk', 29.778671956213657),
#  ('cukier a', 29.777531220024684),
#  ('europejski kod', 29.775536811306665),
#  ('tryba zapytanie', 29.77248415847862),
#  ('napotykać poważny', 29.771754246217824),
#  ('koda sposób', 29.771458134870045),
#  ('cel lub', 29.77101921720896),
#  ('warunek urlop', 29.770264041493647),
#  ('wchodzić arta', 29.769985288148746),
#  ('moment przekroczenie', 29.767624619753406),
#  ('koszty uszlachetniać', 29.767329360511212),
#  ('wyraz niż', 29.764335789484903),
#  ('zakres doradztwo', 29.763928095489973),
#  ('ostatnie dziesięć', 29.763081557244732),
#  ('przypadek dokonanie', 29.76299460529117),
#  ('postawić spółdzielnia', 29.76223486309391),
#  ('antydumpingowy minister', 29.761358772288077),
#  ('sprzedawca olej', 29.760908139147432),
#  ('płatność powiązać', 29.7606732979948),
#  ('oda klient', 29.76055152004119),
#  ('fosfór potas', 29.75992954257572),
#  ('wynik przedreferendalny', 29.757727189899015),
#  ('międzyzwiązkowy bar', 29.756676549979602),
#  ('główny drugorzędny', 29.756110701608122),
#  ('akcyzowy naliczyć', 29.75593150235727),
#  ('miejsce szkoleniowy', 29.754698515047494),
#  ('emisja dwutlenek', 29.754652314062696),
#  ('dzień zgon', 29.754445906553883),
#  ('częsty pisemny', 29.754195889858238),
#  ('apelacja arta', 29.753859550051857),
#  ('fizyczny wykonywać', 29.753408284275793),
#  ('ograniczyć liczba', 29.753258495256887),
#  ('poprzedni lato', 29.753212157345843),
#  ('krwotoczny ryba', 29.75200476048758),
#  ('krwiotwórczy ryba', 29.75200476048758),
#  ('gmina albo', 29.75064128811937),
#  ('powodować negatywny', 29.749596899404423),
#  ('ureaform zawartość', 29.74901979930837),
#  ('rozpocząć robota', 29.74872656368825),
#  ('sieć telefonia', 29.748627808015954),
#  ('tekst z', 29.74815498117823),
#  ('rekreacyjny zarybiać', 29.74744283472728),
#  ('żywność woda', 29.746693899178354),
#  ('taki samo', 29.74662850185996),
#  ('rażący uchybić', 29.746358843299276),
#  ('zrzeszać osoba', 29.745616137050092),
#  ('szkoda arta', 29.745516865630634),
#  ('uprzedni powiadomienie', 29.744036498286732),
#  ('zmiana właściwy', 29.743988975242246),
#  ('dokument dołączyć', 29.74358626762114),
#  ('ekspertyza opinia', 29.743096219921426),
#  ('pozwolić w', 29.74274460808374),
#  ('krajowy organizacja', 29.74258183245547),
#  ('społeczny związać', 29.74142267589923),
#  ('i akcyza', 29.741347617586143),
#  ('i go', 29.741347617586143),
#  ('do zakład', 29.740855635260232),
#  ('towar spod', 29.740457514024456),
#  ('podróżna podróżny', 29.740295463042457),
#  ('stan rzeczywisty', 29.740052552559064),
#  ('lubić wykonanie', 29.7398147364147),
#  ('zaspokoić wszystek', 29.739650384683046),
#  ('organizacja do', 29.73831489123404),
#  ('wieczysty lub', 29.73708149464801),
#  ('pracownica zwalniać', 29.73612468867759),
#  ('postanowić odmawiać', 29.73561570900347),
#  ('dwustopniowy stosować', 29.73476966295857),
#  ('się forma', 29.73383117467165),
#  ('głuchowo pogórska', 29.733458161672672),
#  ('jarosława głuchów', 29.733458161672672),
#  ('rembelszczyzna mory', 29.733458161672672),
#  ('rozwadów strachocina', 29.733458161672672),
#  ('wrona kozienice', 29.733458161672672),
#  ('wrona rozwadów', 29.733458161672672),
#  ('głód pragnienie', 29.733458161672672),
#  ('karmia karm', 29.733458161672672),
#  ('odruch oddechowy', 29.733458161672672),
#  ('opera operetka', 29.733458161672672),
#  ('dziobać dziób', 29.733458161672672),
#  ('wybuchły wybuchnąć', 29.733458161672672),
#  ('zewnętrznie niedostrzegalny', 29.733458161672672),
#  ('monometylodichlorodifenylometan monometylofibromodifenylometan',
#   29.733458161672672),
#  ('anemia isa', 29.733458161672672),
#  ('anemia łosoś', 29.733458161672672),
#  ('salmon anemia', 29.733458161672672),
#  ('strusi struś', 29.733458161672672),
#  ('majdany leśniowski', 29.733458161672672),
#  ('stanowić wkład', 29.726539674869855),
#  ('spowodować ujawnienie', 29.726095547444856),
#  ('praktyka uczniowski', 29.725368198785873),
#  ('liczyć według', 29.72482248504093),
#  ('uzasadnić wskazanie', 29.724811906526156),
#  ('dać niezgodnie', 29.723894156850292),
#  ('teren zdegradować', 29.722976292126987),
#  ('wiek wykonanie', 29.722152904607356),
#  ('otrzymać karty', 29.721338449460745),
#  ('wniosek i', 29.71878721867688),
#  ('wystarczać sieć', 29.718670176651358),
#  ('komisja rozstrzygający', 29.717688669232302),
#  ('wesprzeć tworzenie', 29.71559197643728),
#  ('majątkowy wnioskodawca', 29.715252933150623),
#  ('wodny rzeka', 29.7145591277731),
#  ('eksportowy kraj', 29.71441096605122),
#  ('przyjąć który', 29.71374438237399),
#  ('częstotliwość przekazywać', 29.712019131569832),
#  ('sklep zoologiczny', 29.710822172304233),
#  ('zgłaszać propozycja', 29.70930966081505),
#  ('l metr', 29.708544378212537),
#  ('i przerób', 29.708529665367678),
#  ('informacyjny policja', 29.708224758134747),
#  ('się zakłady', 29.708128757425584),
#  ('poczet dywidenda', 29.70702274517498),
#  ('świadczyć powtarzać', 29.70695329758746),
#  ('witamina a', 29.706816828314913),
#  ('prowadzić wędrowny', 29.706545711669605),
#  ('produktowy od', 29.706337353854906),
#  ('ponowny podjęcie', 29.70625055137498),
#  ('przyznać o', 29.70625024754554),
#  ('ustanowić medal', 29.705740840625367),
#  ('wrak statek', 29.705269056285033),
#  ('nauka religia', 29.70426621561637),
#  ('obecność oskarżony', 29.703713459064602),
#  ('celny wywóz', 29.703602056004456),
#  ('ex haft', 29.703585308534457),
#  ('podwyższyć opłata', 29.70285123729991),
#  ('on zaproponować', 29.702777366968803),
#  ('on wtórnik', 29.702777366968803),
#  ('wyjątek wydatek', 29.70261685099831),
#  ('służyć strona', 29.701734001515433),
#  ('religijny stanowić', 29.70171693339944),
#  ('za umieścić', 29.700219348364044),
#  ('odmawiać wjazd', 29.699942072698832),
#  ('kopać akt', 29.699937894387404),
#  ('dawka dzienny', 29.699412241341633),
#  ('zarządzać wykonanie', 29.69908428641793),
#  ('strzec powaga', 29.69908242483052),
#  ('akceptowalny poziom', 29.6973526120928),
#  ('przestrzegać w', 29.697275586193427),
#  ('rada główny', 29.6972343257803),
#  ('ustawa także', 29.696289870305918),
#  ('ponad wartość', 29.69562651598244),
#  ('z oznaczać', 29.69539048941806),
#  ('posiadać zaległość', 29.694556262387778),
#  ('ojciec wyznaczyć', 29.694344865507446),
#  ('zaufać pomiędzy', 29.694228079119057),
#  ('impreza o', 29.69296096987091),
#  ('zasada kształtować', 29.69211366053787),
#  ('jeden pięćsetny', 29.69198106805561),
#  ('kierować zespół', 29.691296839177085),
#  ('spadek popyt', 29.69121276268652),
#  ('czynność psychiczny', 29.690865839787875),
#  ('działalność sportowy', 29.69031802272366),
#  ('podatek za', 29.69022587616928),
#  ('dotyczyć wyłącznie', 29.690214655624004),
#  ('odróżniać charakter', 29.689563970467134),
#  ('dodatek uzasadniony', 29.688773278125154),
#  ('aptekarski oraz', 29.68864489311818),
#  ('powiadamiać się', 29.68797171697952),
#  ('szczególny cech', 29.687593266615295),
#  ('konkurs konkurs', 29.68717793786709),
#  ('ten organizacyjny', 29.68683343275916),
#  ('na rynka', 29.68626415450126),
#  ('przez prawo', 29.685284942446742),
#  ('a następować', 29.685204770823475),
#  ('powrotnie przywieźć', 29.683442580268547),
#  ('prawidłowy przeprowadzić', 29.6808007754953),
#  ('zezwolić określać', 29.68059629088384),
#  ('rozpuszczalny rozpuszczaln', 29.679850838293987),
#  ('pobierać komórka', 29.679249747518043),
#  ('mecenat państwowy', 29.67836585799523),
#  ('paczka żywnościowy', 29.67789062943666),
#  ('praca przewidujący', 29.677079191606026),
#  ('nieletnia świetlica', 29.67682673035779),
#  ('operacyjny zamieszczać', 29.676296388388437),
#  ('prowadzić środek', 29.675890155078378),
#  ('połowowy wpisywać', 29.674953339515014),
#  ('daleko biuro', 29.674091984059487),
#  ('dotyczeć wszystek', 29.673120076418854),
#  ('metr azot', 29.671988906804472),
#  ('zleceniodawca lub', 29.671470182191115),
#  ('jaka zabezpieczenie', 29.67040577402804),
#  ('lubić istotnie', 29.670121960283723),
#  ('makowy lub', 29.670121960283723),
#  ('pokarmowy lub', 29.670121960283723),
#  ('sprowadzać tkanka', 29.66983148374129),
#  ('każdy bilard', 29.66977641034464),
#  ('każdy ćwiartka', 29.66977641034464),
#  ('tramwajowy tabor', 29.666803311845797),
#  ('tabor tramwajowy', 29.666803311845797),
#  ('prawniczy gdy', 29.666515716031427),
#  ('chorobowe obrażenie', 29.666503877446303),
#  ('wojewódzki komenda', 29.665700295649003),
#  ('nadal jeżeli', 29.664867883286206),
#  ('starosta lub', 29.662888949387707),
#  ('spłatać udzielić', 29.66281389863434),
#  ('opiekun zabytek', 29.6625972335778),
#  ('oraz odpowiedni', 29.661345650674775),
#  ('ważność oddany', 29.661091135298193),
#  ('uzyskać zatwierdzenie', 29.66101952502504),
#  ('wyborca sporządzać', 29.660571925607655),
#  ('taki umówić', 29.660191679977288),
#  ('zwierzęcy mięso', 29.65901024502091),
#  ('rachunek oddział', 29.657243633417238),
#  ('oraz skarbowy', 29.65650294389343),
#  ('instancja sąd', 29.6559768779116),
#  ('ulegać rozkładowy', 29.654734936008026),
#  ('umyślny ciężki', 29.652156266362),
#  ('uchylać zarządzenie', 29.65190529274696),
#  ('wpis przedstawicielstwo', 29.651764530972287),
#  ('tytuł określić', 29.651115937682334),
#  ('ten przeznaczyć', 29.649833436473273),
#  ('zachować jej', 29.64902480498131),
#  ('sprawa także', 29.648212982108817),
#  ('brzeg rzeka', 29.64758982343028),
#  ('pozostawiać wniosek', 29.647077998452005),
#  ('strata majątkowy', 29.646818126231665),
#  ('zgłosić zmiana', 29.645143786561675),
#  ('właściwy ochrona', 29.644682338344865),
#  ('nawet wtedy', 29.643612508377373),
#  ('osoba mieć', 29.643050271144602),
#  ('jeden miejsce', 29.6422327660257),
#  ('skutkować zmiana', 29.641675126200425),
#  ('wynik sondaż', 29.63982592476532),
#  ('akcyjny albo', 29.639564551442163),
#  ('finansowy sporządzać', 29.63771185936639),
#  ('wykonywać umowy', 29.633854802523274),
#  ('przez centrum', 29.633178185729776),
#  ('środek minister', 29.632084832002874),
#  ('rejestr z', 29.631521488074213),
#  ('sprawa inny', 29.631098485027906),
#  ('wzór cech', 29.630822992265166),
#  ('dokument referencyjny', 29.63073583143705),
#  ('interwencja uboczny', 29.63014459585247),
#  ('ochronny zostać', 29.62878867094696),
#  ('jeżeli opóźnienie', 29.628419481479796),
#  ('raz uzyskać', 29.628193641838152),
#  ('niektóry prawić', 29.628101041766058),
#  ('wyborczy konina', 29.627298132851138),
#  ('ukierunkować na', 29.623794154147618),
#  ('dopłata nie', 29.623052748851478),
#  ('ewakuacja ludność', 29.622847915617967),
#  ('on pouczyć', 29.62208519235719),
#  ('rozwiązywać stosunek', 29.620764639890695),
#  ('ustawowy ulga', 29.620232871449844),
#  ('prowadzić leczenie', 29.618529338767985),
#  ('klarowność wyrób', 29.617919464530132),
#  ('wyrób kaletniczy', 29.617919464530132),
#  ('średnioroczny wskaźnikowy', 29.61690722199137),
#  ('konsultacje o', 29.616507648141123),
#  ('jeden reprezentatywny', 29.61482113503007),
#  ('do powiadomienie', 29.614227938465774),
#  ('komornik zwracać', 29.6140374350216),
#  ('istotnie utrudnić', 29.613285516245924),
#  ('dotyczyć tylko', 29.61096739099594),
#  ('hektary użytki', 29.61031344942694),
#  ('do powiat', 29.609919557115063),
#  ('gimnazjum i', 29.609547724714503),
#  ('kontrola materiał', 29.609321290045045),
#  ('rejon zamknięty', 29.608155507286938),
#  ('iv vel', 29.607034356026816),
#  ('doskonały kwalifikacje', 29.606701028500538),
#  ('między stolica', 29.606701028500538),
#  ('polecić doprowadzenie', 29.606350185920746),
#  ('zrekultywować składowisko', 29.605937795820864),
#  ('oraz składka', 29.605244336591568),
#  ('wpłacić w', 29.605117892846465),
#  ('możliwie ścisły', 29.604685959453946),
#  ('założycielski bank', 29.60079435427906),
#  ('inspektor wykonywać', 29.60020111943595),
#  ('potrącenie z', 29.59869788226206),
#  ('chlorek magnez', 29.596792344359983),
#  ('i analizować', 29.59659320616629),
#  ('nazwisko stanowisko', 29.596355252710055),
#  ('pierwsze przetwórca', 29.59546705874891),
#  ('stopień kapral', 29.595307553347084),
#  ('minister kierownica', 29.594667982513783),
#  ('wydatek nieprzewidziany', 29.594534452742664),
#  ('bycie prawidłowo', 29.594325801095692),
#  ('a że', 29.59287241694983),
#  ('uzależniać ważność', 29.592507437504537),
#  ('do obróbka', 29.591653228621),
#  ('polityczny składać', 29.59095111044735),
#  ('odpowiadać początkowy', 29.590181018109433),
#  ('zasada zwrot', 29.590068112767767),
#  ('kontrolować dokument', 29.589909050424467),
#  ('fizyczny imię', 29.58985139348806),
#  ('zagrożenie jaki', 29.58722291772574),
#  ('oferta przewidujący', 29.586428423855978),
#  ('spółka posiadający', 29.58613778790459),
#  ('zakłady zaliczać', 29.585983383607527),
#  ('ojciec szczegółowy', 29.585713246488012),
#  ('molibdenia nawóz', 29.58433227381647),
#  ('nawóz nk', 29.58433227381647),
#  ('nawóz pylisty', 29.58433227381647),
#  ('przez oboj', 29.58374864741927),
#  ('zdać z', 29.583725549047813),
#  ('wspólnik oraz', 29.582861464936286),
#  ('pobierać konserwować', 29.582782960944314),
#  ('zdrowotny bezpłatnie', 29.582585359661607),
#  ('tabliczka z', 29.582444805069827),
#  ('zakupić budowa', 29.58080545165285),
#  ('nawozowy rozpuszczalność', 29.57948480877394),
#  ('samorząd aptekarski', 29.578721017598582),
#  ('tytuł realizacja', 29.57670285408676),
#  ('kraj bar', 29.576303881418426),
#  ('płatność odroczyć', 29.575995493178198),
#  ('uwzględnić orzecznictwo', 29.57541799192404),
#  ('bezpośrednio z', 29.574775114655495),
#  ('pojedynczy przeznaczyć', 29.572794083549525),
#  ('smarowy włącznie', 29.57240541383544),
#  ('trykot wszelki', 29.570888551950702),
#  ('zamknąć dochodzenie', 29.57013345852647),
#  ('górotwór wóda', 29.56969525088425),
#  ('przestępstwo oraz', 29.565319846384227),
#  ('taki czynności', 29.564918312826194),
#  ('rok przy', 29.562954678665847),
#  ('teatralny im', 29.56259980694449),
#  ('zasadniczy dodatek', 29.558649832695664),
#  ('wyjaśnić czy', 29.558209376096784),
#  ('koszty świadczenie', 29.557500496623106),
#  ('do własny', 29.556836864794604),
#  ('krajowy określić', 29.55619946832303),
#  ('z e', 29.555475314729847),
#  ('wiek majątek', 29.554539853241295),
#  ('wymieszać wkład', 29.554328208163497),
#  ('nbp określać', 29.553650903282687),
#  ('sąd odraczać', 29.553496756925597),
#  ('wszyscy akcjonariusz', 29.553329319969635),
#  ('wydzielić subkonto', 29.551881607785617),
#  ('inny komunalny', 29.5514101353765),
#  ('schronisko turystyczny', 29.550361649129627),
#  ('oraz maszyna', 29.550182434322778),
#  ('użytkowy oraz', 29.550182434322778),
#  ('pozycja bilans', 29.550074763246812),
#  ('produkować zazwyczaj', 29.549856357820772),
#  ('ubezwłasnowolnić prawomocny', 29.548160743443077),
#  ('oraz koordynować', 29.547859987826087),
#  ('się istotnie', 29.547809226438403),
#  ('wełna zgrzeblić', 29.546957864441083),
#  ('wewnątrzszkolny system', 29.546737698627112),
#  ('mnożnikowym system', 29.546737698627112),
#  ('opisowy operat', 29.54648548751311),
#  ('czysty chemicznie', 29.54593703859973),
#  ('program zrównoważony', 29.54520292473171),
#  ('liczba który', 29.5444654119201),
#  ('przewozić roślina', 29.544077595564886),
#  ('według swój', 29.54309399992053),
#  ('nabyć wcześnie', 29.542667084977438),
#  ('przedstawiać projekt', 29.540966751366796),
#  ('wojskowy i', 29.53914290398825),
#  ('rok dokonać', 29.538372150738724),
#  ('zdrowotny w', 29.537216155556962),
#  ('przegląd i', 29.5366564784199),
#  ('mieszkaniowy bar', 29.533585154029424),
#  ('jeden kilometr', 29.533429391594836),
#  ('za wyszkolenie', 29.530998012894997),
#  ('tworzyć baza', 29.530723815052625),
#  ('po dany', 29.530687562422827),
#  ...]

# %%
serialize('llr_dict.pickle', llr_dict)

# %% [markdown]
# Which measure works better for the problem?

# %% [markdown]
# LLR is more suitable than PMI

# %% [markdown]
# What would be needed, besides good measure, to build a dictionary of multiword expressions?

# %% [markdown]
# Good lemmatization and tokenization

# %% [markdown]
# Can you identify a certain threshold which clearly divides the good expressions from the bad?

# %%
30
# Out:
# 30
