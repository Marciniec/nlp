# %% [markdown]
# # Word embeddings
# ## Solution of https://github.com/apohllo/nlp/blob/master/7-embeddings.md

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
import numpy as np

# %%
wv_from_text = KeyedVectors.load_word2vec_format(datapath('/home/countess/Documents/Studies/VIII Semester/NLP/nlp/7-embeddings/skipgram/skip_gram_v100m8.w2v.txt'), binary=False)  # C text format

# %%
wv_from_text.wv.vocab
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# {'w::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17e588>,
#  'i::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b17e710>,
#  'być::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b17e748>,
#  'z::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17e7b8>,
#  'na::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17e7f0>,
#  'nie::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b17e828>,
#  'on::pron': <gensim.models.keyedvectors.Vocab at 0x7f473b17e860>,
#  'do::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17e898>,
#  'ten::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b17e8d0>,
#  'że::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b17e908>,
#  'to::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b17e940>,
#  'który::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b17e978>,
#  'a::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b17e9e8>,
#  'o::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17ea58>,
#  'mieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b17ea90>,
#  'jak::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b17eac8>,
#  'po::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17eb00>,
#  'to::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b17eb38>,
#  'ja::pron': <gensim.models.keyedvectors.Vocab at 0x7f473b17eb70>,
#  'ale::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b17eba8>,
#  'od::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17ebe0>,
#  'rok::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b17ec18>,
#  'móc::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b17ec50>,
#  'za::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17ec88>,
#  'bardzo::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b17ecc0>,
#  'przez::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17ecf8>,
#  'CO::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b17ed30>,
#  'dla::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b17ed68>,
#  'polecać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b17eda0>,
#  'taki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b17edd8>,
#  'tak::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b17ee10>,
#  'swój::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b17ee48>,
#  'i::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b17eeb8>,
#  'już::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b17eef0>,
#  'się::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b17ef28>,
#  'by::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b17ef98>,
#  'wszystko::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b17efd0>,
#  'oraz::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193048>,
#  'czy::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193080>,
#  'siebie::pron': <gensim.models.keyedvectors.Vocab at 0x7f473b1930b8>,
#  'inny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1930f0>,
#  'tylko::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193128>,
#  'jeden::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193160>,
#  'zostać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b193198>,
#  'czas::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1931d0>,
#  'sam::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193208>,
#  'dobry::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193240>,
#  'chcieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b193278>,
#  'bo::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1932b0>,
#  '1::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193320>,
#  'my::pron': <gensim.models.keyedvectors.Vocab at 0x7f473b193358>,
#  'mój::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193390>,
#  'człowiek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1933c8>,
#  'nasz::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193400>,
#  'jeszcze::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193438>,
#  'też::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193470>,
#  'przy::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1934a8>,
#  'pierwszy::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1934e0>,
#  'jednak::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193518>,
#  'przed::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b193550>,
#  'to::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193588>,
#  'mówić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1935c0>,
#  'wiedzieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1935f8>,
#  'dzień::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193630>,
#  'Pan::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193668>,
#  'dwa::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1936a0>,
#  'wszystek::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1936d8>,
#  'miejsce::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193710>,
#  'ty::pron': <gensim.models.keyedvectors.Vocab at 0x7f473b193748>,
#  'praca::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193780>,
#  'nowy::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1937b8>,
#  'można::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1937f0>,
#  'musieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b193828>,
#  'lub::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193860>,
#  'duży::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193898>,
#  'jaki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1938d0>,
#  'pod::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b193908>,
#  'także::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193940>,
#  'osoba::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193978>,
#  'sprawa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1939b0>,
#  'każdy::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1939e8>,
#  'powiedzieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b193a20>,
#  'cały::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193a58>,
#  'raz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193a90>,
#  'nawet::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193ac8>,
#  'dobrze::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b193b00>,
#  'bez::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b193b38>,
#  'R::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193ba8>,
#  'więc::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193be0>,
#  'jeśli::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193c18>,
#  'wiele::num': <gensim.models.keyedvectors.Vocab at 0x7f473b193c50>,
#  'strona::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193c88>,
#  'również::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b193cc0>,
#  'dziecko::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b193cf8>,
#  'drugi::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193d30>,
#  'gdy::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b193d68>,
#  'jako::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193da0>,
#  'si::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193e10>,
#  'aby::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193e48>,
#  '2::num': <gensim.models.keyedvectors.Vocab at 0x7f473b193eb8>,
#  'kiedy::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b193ef0>,
#  'kilka::num': <gensim.models.keyedvectors.Vocab at 0x7f473b193f28>,
#  'jakiś::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b193f60>,
#  'by::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b193f98>,
#  'teraz::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b193fd0>,
#  'tu::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b199080>,
#  'coś::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1990b8>,
#  'życie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1990f0>,
#  'powinien::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b199128>,
#  'nic::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199160>,
#  'kontakt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199198>,
#  'maić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1991d0>,
#  'żeby::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b199208>,
#  'tam::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b199240>,
#  'nad::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b199278>,
#  'problem::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1992b0>,
#  'czy::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1992e8>,
#  'szybko::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b199320>,
#  'gdzie::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b199358>,
#  'sposób::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199390>,
#  'może::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1993c8>,
#  'u::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b199438>,
#  'szybki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b199470>,
#  'to::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1994e0>,
#  'co::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199518>,
#  'godzina::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199550>,
#  'firma::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199588>,
#  'miasto::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1995c0>,
#  '3::num': <gensim.models.keyedvectors.Vocab at 0x7f473b199630>,
#  'transakcja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199668>,
#  'napisać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1996a0>,
#  'ostatni::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1996d8>,
#  'należeć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b199710>,
#  'kolejny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b199748>,
#  'trzeba::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b199780>,
#  'wysoki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1997b8>,
#  'wielki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1997f0>,
#  'mały::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b199828>,
#  'kto::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199860>,
#  'prawo::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199898>,
#  'chodzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1998d0>,
#  'część::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199908>,
#  '5::num': <gensim.models.keyedvectors.Vocab at 0x7f473b199978>,
#  'pewien::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1999b0>,
#  'oko::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1999e8>,
#  'cel::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199a20>,
#  'żaden::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b199a58>,
#  'M::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199ac8>,
#  'chwila::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199b00>,
#  'sytuacja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199b38>,
#  'mecz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199b70>,
#  'zrobić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b199ba8>,
#  'pani::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199be0>,
#  'temat::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199c18>,
#  'spotkanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199c50>,
#  '2::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b199cc0>,
#  'no::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b199d30>,
#  'dom::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199d68>,
#  'podczas::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b199da0>,
#  'prowadzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b199dd8>,
#  'zespół::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199e10>,
#  'widzieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b199e48>,
#  'ktoś::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199e80>,
#  'projekt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199eb8>,
#  'trzy::num': <gensim.models.keyedvectors.Vocab at 0x7f473b199ef0>,
#  'około::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199f28>,
#  'droga::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199f60>,
#  'informacja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199f98>,
#  'państwo::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b199fd0>,
#  'ulica::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c048>,
#  'grupa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c080>,
#  'chyba::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b19c0b8>,
#  'zmiana::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c0f0>,
#  'ważny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c128>,
#  '0::num': <gensim.models.keyedvectors.Vocab at 0x7f473b19c198>,
#  '3::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c208>,
#  'właśnie::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b19c240>,
#  'ne#zł::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c278>,
#  'albo::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c2b0>,
#  'dotyczyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19c2e8>,
#  'przypadek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c320>,
#  '4::num': <gensim.models.keyedvectors.Vocab at 0x7f473b19c390>,
#  'zawsze::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b19c3c8>,
#  'pytanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c400>,
#  'kraj::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c438>,
#  'koniec::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c470>,
#  'niż::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c4a8>,
#  'własny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c4e0>,
#  'robić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19c518>,
#  'wszyscy::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c550>,
#  'towar::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c588>,
#  'na_przykład::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c5c0>,
#  'stan::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c5f8>,
#  'szkoła::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c630>,
#  'dlatego::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b19c668>,
#  'prosty::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c6a0>,
#  'często::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b19c6d8>,
#  'uwaga::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c710>,
#  'czyli::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c748>,
#  'pomoc::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c780>,
#  '10::num': <gensim.models.keyedvectors.Vocab at 0x7f473b19c7f0>,
#  'pozdrawiać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19c828>,
#  'wtedy::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b19c860>,
#  'myśleć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19c898>,
#  'ustawa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c8d0>,
#  'stary::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19c908>,
#  'możliwość::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c940>,
#  'rzecz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c978>,
#  'poseł::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19c9b0>,
#  'potem::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b19c9e8>,
#  'program::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19ca20>,
#  'jeżeli::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b19ca58>,
#  'dziękować::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19ca90>,
#  'różny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19cac8>,
#  'udział::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cb00>,
#  'słowo::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cb38>,
#  'dać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19cb70>,
#  'prosić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19cba8>,
#  'tylko::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b19cbe0>,
#  'gmina::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cc18>,
#  '100::num': <gensim.models.keyedvectors.Vocab at 0x7f473b19cc50>,
#  'środek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cc88>,
#  'młody::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19ccc0>,
#  'twój::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b19ccf8>,
#  'minuta::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cd30>,
#  'system::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cd68>,
#  'wynik::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cda0>,
#  'pisać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19cdd8>,
#  'głowa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19ce10>,
#  'więcej::num': <gensim.models.keyedvectors.Vocab at 0x7f473b19ce48>,
#  'oczywiście::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b19ce80>,
#  'kobieta::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19ceb8>,
#  'ręka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cef0>,
#  'dzięki::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b19cf28>,
#  'opis::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b19cf60>,
#  'stać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b19cf98>,
#  'ani::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b19cfd0>,
#  'nikt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0048>,
#  'tak::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0080>,
#  'woda::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a00b8>,
#  'pieniądz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a00f0>,
#  'między::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0128>,
#  'grać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0160>,
#  'gra::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0198>,
#  'gdyby::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a01d0>,
#  'uważać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0208>,
#  'natomiast::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0240>,
#  'Świat::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0278>,
#  'zacząć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a02b0>,
#  'miesiąc::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a02e8>,
#  'teren::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0320>,
#  'późno::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0358>,
#  '6::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a03c8>,
#  'cena::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0400>,
#  'zdanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0438>,
#  'ne#Polsce::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0470>,
#  'daleko::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a04a8>,
#  'iż::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a04e0>,
#  'jak::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0518>,
#  'poza::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0550>,
#  'klub::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0588>,
#  '30::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a05f8>,
#  'wy::pron': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0630>,
#  'początek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0668>,
#  'znać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a06a0>,
#  'lecz::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a06d8>,
#  '20::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0748>,
#  'punkt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0780>,
#  'przecież::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a07b8>,
#  'rząd::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a07f0>,
#  'wniosek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0828>,
#  'super::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0860>,
#  'okres::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0898>,
#  'choć::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a08d0>,
#  'pełny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0908>,
#  'iść::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0940>,
#  'decyzja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0978>,
#  'nigdy::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a09b0>,
#  'prawda::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a09e8>,
#  'działanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0a20>,
#  'znajdować_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0a58>,
#  'milion::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0a90>,
#  'otrzymać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0ac8>,
#  'P::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0b38>,
#  'gorąco::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0b70>,
#  'pracować::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0ba8>,
#  'mieszkaniec::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0be0>,
#  'akcja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0c18>,
#  'głos::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0c50>,
#  'stać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0c88>,
#  'rodzina::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0cc0>,
#  'związać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0cf8>,
#  '00::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0d68>,
#  'autor::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0da0>,
#  'tydzień::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0dd8>,
#  'wiek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0e10>,
#  'działać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0e48>,
#  'zasada::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0e80>,
#  'powód::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0eb8>,
#  'ponieważ::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0ef0>,
#  'książka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0f28>,
#  'istnieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0f60>,
#  'zakres::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0f98>,
#  'ponad::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a0fd0>,
#  'czekać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5048>,
#  'forma::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5080>,
#  'dopiero::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a50b8>,
#  'dlaczego::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a50f0>,
#  'drużyna::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5128>,
#  'historia::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5160>,
#  'stanowić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5198>,
#  'sprawnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a51d0>,
#  '15::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5240>,
#  'niektóry::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5278>,
#  'mimo::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1a52b0>,
#  'władza::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a52e8>,
#  'naprawdę::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5320>,
#  'oba::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5358>,
#  'przykład::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5390>,
#  'tutaj::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a53c8>,
#  'odbyć_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5400>,
#  'zobaczyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5438>,
#  'posiadać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5470>,
#  'główny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a54a8>,
#  'dziś::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a54e0>,
#  'niestety::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5518>,
#  'pracownik::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5550>,
#  'związek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5588>,
#  'znaleźć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a55c0>,
#  '4::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5630>,
#  'plac::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5668>,
#  'klasa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a56a0>,
#  'pozytyw::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a56d8>,
#  'ile::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5710>,
#  'minister::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5748>,
#  'tytuł::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5780>,
#  'dawać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a57b8>,
#  'działalność::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a57f0>,
#  'wczesno::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5828>,
#  'zły::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5860>,
#  'wzgląd::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5898>,
#  'zawodnik::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a58d0>,
#  'uczeń::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5908>,
#  'tys::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5940>,
#  'ne#Polski::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5978>,
#  'umowa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a59b0>,
#  'film::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a59e8>,
#  'udać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5a20>,
#  'sezon::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5a58>,
#  'podstawa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5a90>,
#  'komisja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5ac8>,
#  'wśród::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5b00>,
#  'zgodny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5b38>,
#  'użytkownik::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5b70>,
#  'koszt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5ba8>,
#  'OK::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5c18>,
#  'przepis::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5c50>,
#  'obecnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5c88>,
#  'badanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5cc0>,
#  'wziąć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5cf8>,
#  '5::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5d68>,
#  'wyglądać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5da0>,
#  'wydawać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5dd8>,
#  'nr::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5e10>,
#  'długi::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5e48>,
#  'dużo::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5e80>,
#  'siła::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5eb8>,
#  'fakt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5ef0>,
#  'brak::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5f28>,
#  'członek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5f60>,
#  'zadanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5f98>,
#  'art::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1a5fd0>,
#  'samochód::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac048>,
#  'zgodnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac080>,
#  'S::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac0f0>,
#  'Nadzieja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac128>,
#  'liczba::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac160>,
#  'okazja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac198>,
#  'potrafić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac1d0>,
#  'aż::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac208>,
#  'większość::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac240>,
#  'ciekawy::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac278>,
#  'polski::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac2b0>,
#  'dyrektor::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac2e8>,
#  'jedynie::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac320>,
#  '12::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac390>,
#  'ojciec::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac3c8>,
#  'mężczyzna::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac400>,
#  'rozumieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac438>,
#  'poziom::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac470>,
#  '7::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac4e0>,
#  'Ziemia::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac518>,
#  'dodać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac550>,
#  '8::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac5c0>,
#  'brać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac5f8>,
#  'temu::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac630>,
#  'konkurs::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac668>,
#  'żyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac6a0>,
#  'co::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac6d8>,
#  'bowiem::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac710>,
#  'rodzaj::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac748>,
#  'mało::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac780>,
#  'budynek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac7b8>,
#  'gość::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac7f0>,
#  'typ::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac828>,
#  'odpowiedź::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac860>,
#  'bliski::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac898>,
#  'wartość::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac8d0>,
#  'pamiętać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac908>,
#  'dana::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac940>,
#  'coraz::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac978>,
#  'rozwój::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac9b0>,
#  'walka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1ac9e8>,
#  'trzeci::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1aca20>,
#  'według::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1aca58>,
#  'prawie::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1aca90>,
#  'szansa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acac8>,
#  'klient::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acb00>,
#  'potrzeba::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acb38>,
#  'przesyłka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acb70>,
#  'trochę::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1acba8>,
#  'podobny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1acbe0>,
#  'bramka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acc18>,
#  'tysiąc::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acc50>,
#  'jedyny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1acc88>,
#  'wynikać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1accc0>,
#  'sprzedawca::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1accf8>,
#  'moment::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acd30>,
#  'za::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1acda0>,
#  'rynek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acdd8>,
#  'okazać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ace10>,
#  'miły::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1ace48>,
#  'trwać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1ace80>,
#  'myśl::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1aceb8>,
#  'wymagać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1acef0>,
#  'przyjąć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1acf28>,
#  'proca::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acf60>,
#  'plan::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1acf98>,
#  'cztery::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1acfd0>,
#  'dojść::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af048>,
#  'gdyż::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1af080>,
#  'około::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1af0b8>,
#  'realizacja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af0f0>,
#  'postać::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af128>,
#  'śmierć::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af160>,
#  'co::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1af198>,
#  'na_pewno::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1af1d0>,
#  'nie::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1af208>,
#  'zbyt::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1af240>,
#  'zaś::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1af278>,
#  'inaczej::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af2b0>,
#  'tyle::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1af2e8>,
#  'obecny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1af320>,
#  'długo::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1af358>,
#  'budowa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af390>,
#  'nazwa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af3c8>,
#  'dzisiaj::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1af400>,
#  'serdecznie::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1af438>,
#  'przyjść::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af470>,
#  '10::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1af4e0>,
#  'ramy::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af518>,
#  'warto::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af550>,
#  'zdobyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af588>,
#  'wyjść::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af5c0>,
#  '50::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1af630>,
#  'E::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af6a0>,
#  'trener::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af6d8>,
#  'współpraca::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af710>,
#  'rozmowa::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af748>,
#  'świadek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af780>,
#  'proces::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af7b8>,
#  'czytać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af7f0>,
#  'wybrać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af828>,
#  'usta::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af860>,
#  'dostać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1af898>,
#  'organizacja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af8d0>,
#  'bieżącego/bieżącym_roku::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af908>,
#  'prezes::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1af940>,
#  'piękny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1af978>,
#  'wobec::prep': <gensim.models.keyedvectors.Vocab at 0x7f473b1af9b0>,
#  '6::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1afa20>,
#  'rozwiązanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afa58>,
#  'ciało::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afa90>,
#  'granica::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afac8>,
#  'stanowisko::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afb00>,
#  'zapraszać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1afb38>,
#  'sąd::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afb70>,
#  'przygotować::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1afba8>,
#  'termin::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afbe0>,
#  'szukać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1afc18>,
#  'twarz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afc50>,
#  'wykonać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1afc88>,
#  'wiadomość::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afcc0>,
#  'kwestia::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afcf8>,
#  'oferta::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afd30>,
#  'rola::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afd68>,
#  'mieszkanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afda0>,
#  'powiat::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afdd8>,
#  'kierunek::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1afe10>,
#  'zarówno::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1afe48>,
#  'liczyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1afe80>,
#  'prawdziwy::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1afeb8>,
#  '11::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1aff28>,
#  'prezydent::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1aff60>,
#  'dokument::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1aff98>,
#  'B::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5048>,
#  'pójść::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5080>,
#  'maj::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b50b8>,
#  'odpowiedni::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b50f0>,
#  'następny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5128>,
#  'ksiądz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5160>,
#  'daleki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5198>,
#  'zmienić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b51d0>,
#  '9::num': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5240>,
#  'świat::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5278>,
#  'serce::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b52b0>,
#  'wrócić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b52e8>,
#  'artykuł::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5320>,
#  'wiedza::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5358>,
#  '17::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b53c8>,
#  'oznaczać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5400>,
#  'noc::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5438>,
#  'rodzic::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5470>,
#  'ii::interj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b54a8>,
#  'D::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5518>,
#  'matka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5550>,
#  'spółka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5588>,
#  'Ruch::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b55c0>,
#  'lubić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b55f8>,
#  'element::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5630>,
#  'nadal::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5668>,
#  'dość::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1b56a0>,
#  'wspólny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b56d8>,
#  'wpływ::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5710>,
#  'tekst::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5748>,
#  'impreza::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5780>,
#  'pokój::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b57b8>,
#  'wszelki::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b57f0>,
#  'nauka::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5828>,
#  'materiał::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5860>,
#  'znaleźć_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5898>,
#  'góra::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b58d0>,
#  'stwierdzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5908>,
#  'pojawić_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5940>,
#  'przeprowadzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5978>,
#  'policja::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b59b0>,
#  'powstać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b59e8>,
#  'doświadczenie::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5a20>,
#  'niech::qub': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5a58>,
#  'produkt::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5a90>,
#  'właściciel::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5ac8>,
#  'pozwolić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5b00>,
#  'trudny::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5b38>,
#  'znany::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5b70>,
#  'próbować::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5ba8>,
#  'wczoraj::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5be0>,
#  'letni::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5c18>,
#  'kupić::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5c50>,
#  'C::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5cc0>,
#  'drzwi::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5cf8>,
#  'wysokość::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5d30>,
#  'obraz::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5d68>,
#  'opinia::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5da0>,
#  'jak::conj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5dd8>,
#  'witać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5e10>,
#  'występować::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5e48>,
#  'zakup::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5e80>,
#  '11::adj': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5ef0>,
#  'szczególnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5f28>,
#  'stopień::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5f60>,
#  'pozwalać::verb': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5f98>,
#  'przedstawiciel::noun': <gensim.models.keyedvectors.Vocab at 0x7f473b1b5fd0>,
#  'język::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9048>,
#  'trudno::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9080>,
#  'wygrać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a90b8>,
#  'profesor::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a90f0>,
#  'twierdzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9128>,
#  '12::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9198>,
#  'usługa::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a91d0>,
#  'ilość::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9208>,
#  'pomóc::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9240>,
#  'trafić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9278>,
#  'przedmiot::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a92b0>,
#  '16::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9320>,
#  'pozycja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9358>,
#  'jakby::conj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9390>,
#  'polityczny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a93c8>,
#  'używać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9400>,
#  'syn::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9438>,
#  'miłość::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9470>,
#  'nagroda::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a94a8>,
#  '7::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9518>,
#  'pewnie::qub': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9550>,
#  'piłkarz::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9588>,
#  'zupełnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a95c0>,
#  'lekarz::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a95f8>,
#  'rada::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9630>,
#  'możliwy::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9668>,
#  'skład::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a96a0>,
#  'podać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a96d8>,
#  'sprzedaż::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9710>,
#  'społeczny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9748>,
#  'telefon::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9780>,
#  'kiedyś::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a97b8>,
#  'kilometr::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a97f0>,
#  'warunki::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9828>,
#  'pomysł::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9860>,
#  'efekt::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9898>,
#  'odpowiedzieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a98d0>,
#  'N::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9940>,
#  'wojna::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9978>,
#  'przedstawić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a99b0>,
#  'wypadek::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a99e8>,
#  'obowiązek::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9a20>,
#  '8::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9a90>,
#  'znaczenie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9ac8>,
#  'dużo::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9b00>,
#  'ogromny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9b38>,
#  'kościół::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9b70>,
#  'o::interj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9ba8>,
#  'uczestnik::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9be0>,
#  'niski::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9c18>,
#  'poprzez::prep': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9c50>,
#  '25::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9cc0>,
#  'uznać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9cf8>,
#  '13::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9d68>,
#  'wydać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9da0>,
#  'charakter::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9dd8>,
#  'połowa::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9e10>,
#  'niż::prep': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9e48>,
#  'publiczny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9e80>,
#  'jakość::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9eb8>,
#  'wiadomo::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9ef0>,
#  'finansowy::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9f28>,
#  'starać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9f60>,
#  'wraz::burk': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9f98>,
#  'wrzesień::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6a9fd0>,
#  'zawierać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae048>,
#  'kwota::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae080>,
#  'skoro::conj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae0b8>,
#  'ciąg::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae0f0>,
#  'słyszeć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae128>,
#  'uzyskać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae160>,
#  'zauważyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae198>,
#  'dodatkowy::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae1d0>,
#  'tworzyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae208>,
#  '14::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae278>,
#  'wówczas::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae2b0>,
#  'zwłaszcza::qub': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae2e8>,
#  'tzw::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae320>,
#  'wierzyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae358>,
#  'dyskusja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae390>,
#  'odpowiadać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae3c8>,
#  'funkcja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae400>,
#  'mniej::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae438>,
#  'w_końcu::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae470>,
#  'następnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae4a8>,
#  'liga::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae4e0>,
#  'kolega::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae518>,
#  'młodzież::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae550>,
#  'wybór::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae588>,
#  'pies::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae5c0>,
#  'styczeń::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae5f8>,
#  'źródło::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae630>,
#  'sklep::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae668>,
#  'sztuka::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae6a0>,
#  'produkcja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae6d8>,
#  'podjąć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae710>,
#  'mieszkać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae748>,
#  'podobnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae780>,
#  'czerwiec::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae7b8>,
#  'widać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae7f0>,
#  'warunek::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae828>,
#  '40::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae898>,
#  'obiekt::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae8d0>,
#  '18::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae940>,
#  'zdjęcia::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae978>,
#  'wejść::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae9b0>,
#  'wersja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6ae9e8>,
#  '18::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6aea58>,
# ...
#  'ludzki::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b91d0>,
#  'zagrać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9208>,
#  'wynosić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9240>,
#  'zależeć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9278>,
#  'polegać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b92b0>,
#  'teza::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b92e8>,
#  'zarząd::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9320>,
#  'stracić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9358>,
#  'kategoria::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9390>,
#  'zająć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b93c8>,
#  'stosunek::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9400>,
#  'pora::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9438>,
#  'gospodarczy::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9470>,
#  'godny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b94a8>,
#  'udany::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b94e0>,
#  'numer::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9518>,
#  'juz::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9550>,
#  'pewność::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9588>,
#  'prawny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b95c0>,
#  'silny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b95f8>,
#  'październik::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9630>,
#  'wysłać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9668>,
#  'obok::prep': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b96a0>,
#  'wykonywać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b96d8>,
#  'wzrost::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9710>,
#  'właściwy::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9748>,
#  'wchodzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9780>,
#  'stworzyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b97b8>,
#  'potrzebować::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b97f0>,
#  'przyczyna::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9828>,
#  'czuć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9860>,
#  'dokonać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9898>,
#  'znów::qub': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b98d0>,
#  'przeznaczyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9908>,
#  'urządzenie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9940>,
#  '13::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b99b0>,
#  'pozostawać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b99e8>,
#  '9::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9a58>,
#  'koncert::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9a90>,
#  'K::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9b00>,
#  'czarny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9b38>,
#  'kwiecień::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9b70>,
#  'lipiec::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9ba8>,
#  'światło::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9be0>,
#  'instytucja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9c18>,
#  'kierowca::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9c50>,
#  'poprawka::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9c88>,
#  'itp::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9cc0>,
#  'bezpieczeństwo::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9cf8>,
#  'rozmawiać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9d30>,
#  'listopad::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9d68>,
#  'cieszyć_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9da0>,
#  'szef::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9dd8>,
#  'lista::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9e10>,
#  'zwykle::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9e48>,
#  'obszar::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9e80>,
#  'prawdopodobnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9eb8>,
#  'dotrzeć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9ef0>,
#  'L::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9f60>,
#  'przebiec::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9f98>,
#  'zajmować_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6b9fd0>,
#  'wieś::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd048>,
#  'istotny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd080>,
#  'budżet::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd0b8>,
#  'ochrona::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd0f0>,
#  '20::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd160>,
#  'ku::prep': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd198>,
#  'dać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd1d0>,
#  'racja::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd208>,
#  'zwycięstwo::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd240>,
#  'nieco::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd278>,
#  'wcale::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd2b0>,
#  'okno::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd2e8>,
#  'okolica::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd320>,
#  'zwierzę::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd358>,
#  'biały::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd390>,
#  'nagle::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd3c8>,
#  'list::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd400>,
#  'oddział::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd438>,
#  'kolej::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd470>,
#  'służba::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd4a8>,
#  'postanowić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd4e0>,
#  'uczestniczyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd518>,
#  'miał::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd550>,
#  'mąż::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd588>,
#  'wykorzystać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd5c0>,
#  'sierpień::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd5f8>,
#  'wydarzenie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd630>,
#  'mieć_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd668>,
#  'oprócz::prep': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd6a0>,
#  'zawrzeć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd6d8>,
#  'wprowadzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd710>,
#  'wystawa::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd748>,
#  'wystąpić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd780>,
#  'zrozumieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd7b8>,
#  'choroba::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd7f0>,
#  'poważny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd828>,
#  'konto::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd860>,
#  'bank::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd898>,
#  'przyszłość::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd8d0>,
#  'krok::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd908>,
#  'płyta::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd940>,
#  'zorganizować::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd978>,
#  'tyle::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd9b0>,
#  'ponownie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bd9e8>,
#  'wspaniały::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bda20>,
#  'turniej::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bda58>,
#  'na_razie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bda90>,
#  'luty::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdac8>,
#  'błyskawiczny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdb00>,
#  'przyszły::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdb38>,
#  'zabawa::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdb70>,
#  'mocno::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdba8>,
#  '22::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdc18>,
#  'otworzyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdc50>,
#  'chłopiec::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdc88>,
#  'spowodować::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdcc0>,
#  'ne#Boga::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdcf8>,
#  'news::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdd30>,
#  'jasny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdd68>,
#  'stanąć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdda0>,
#  'ściana::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bddd8>,
#  'szeroki::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bde10>,
#  'pomyśleć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bde48>,
#  'wolny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bde80>,
#  'przedsiębiorstwo::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdeb8>,
#  'parę::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdef0>,
#  'porządek::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdf28>,
#  'ramię::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdf60>,
#  'dziwny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdf98>,
#  'dokładnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6bdfd0>,
#  'powierzchnia::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2048>,
#  'ponadto::qub': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2080>,
#  'zapewniać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c20b8>,
#  'zaczynać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c20f0>,
#  'planować::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2128>,
#  'spojrzeć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2160>,
#  'sobota::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2198>,
#  'wracać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c21d0>,
#  'nazwisko::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2208>,
#  '22::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2278>,
#  'obsługa::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c22b0>,
#  'krew::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c22e8>,
#  'przeciwko::prep': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2320>,
#  'pismo::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2358>,
#  'gospodarz::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2390>,
#  'radny::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c23c8>,
#  'niedziela::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2400>,
#  '19::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2470>,
#  'niemal::qub': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c24a8>,
#  'komentarz::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c24e0>,
#  'poznać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2518>,
#  'wskazywać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2550>,
#  'urząd::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2588>,
#  'treść::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c25c0>,
#  'przypomnieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c25f8>,
#  'wychodzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2630>,
#  'dowiedzieć_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2668>,
#  'drzewo::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c26a0>,
#  'dany::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c26d8>,
#  'przewodniczący::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2710>,
#  'próba::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2748>,
#  'pozytywny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2780>,
#  'czuć_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c27b8>,
#  'rzeczywiście::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c27f0>,
#  'organizować::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2828>,
#  'poszczególny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2860>,
#  'styl::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2898>,
#  'mowa::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c28d0>,
#  'boisko::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2908>,
#  'całość::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2940>,
#  'mistrz::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2978>,
#  'trzymać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c29b0>,
#  'RE::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c29e8>,
#  'wyraźnie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2a20>,
#  'wspomnieć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2a58>,
#  'dodawać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2a90>,
#  'kolor::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2ac8>,
#  'umiejętność::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2b00>,
#  'scena::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2b38>,
#  'przekazać::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2b70>,
#  'odbywać_się::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2ba8>,
#  'postępowanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2be0>,
#  'Król::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2c18>,
#  'metr::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2c50>,
#  'zgoda::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2c88>,
#  'ne#Warszawie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2cc0>,
#  'sprawdzić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2cf8>,
#  'student::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2d30>,
#  'post::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2d68>,
#  'ne#złotych::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2da0>,
#  'wyłącznie::adv': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2dd8>,
#  'zainteresowanie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2e10>,
#  'etap::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2e48>,
#  'różnica::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2e80>,
#  'zadowolony::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2eb8>,
#  'szczególny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2ef0>,
#  'iii::interj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2f28>,
#  'wasz::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2f60>,
#  'realizować::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2f98>,
#  'położyć::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c2fd0>,
#  'doskonały::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9048>,
#  'zanim::conj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9080>,
#  'liczny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c90b8>,
#  'zapis::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c90f0>,
#  'płacić::verb': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9128>,
#  'studia::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9160>,
#  'były::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9198>,
#  'prywatny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c91d0>,
#  'województwo::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9208>,
#  'tamten::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9240>,
#  'w_porządku::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9278>,
#  'm.in::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c92b0>,
#  'ne#Krakowie::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c92e8>,
#  'las::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9320>,
#  'Partia::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9358>,
#  '000::num': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9390>,
#  'podatek::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c93c8>,
#  'powietrze::noun': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9400>,
#  '2007::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9438>,
#  'niewielki::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c9470>,
#  'dostępny::adj': <gensim.models.keyedvectors.Vocab at 0x7f46ff6c94a8>,
#  ...}

# %%
wv_from_text.most_similar(positive=['ne#Wysoki_Sąd::noun'])
# Out:
# [('ne#Ława_Przysięgłych::noun', 0.7620543241500854),
#  ('ne#Wysokiego_Sądu::noun', 0.7618086934089661),
#  ('ne#Maria_Russell::noun', 0.7604403495788574),
#  ('ne#Stache::noun', 0.7588119506835938),
#  ('ne#Wysokiemu_Sądowi::noun', 0.7583813071250916),
#  ('ne#Peltro::noun', 0.7581096291542053),
#  ('ne#Hossack::noun', 0.7576600313186646),
#  ('ne#Hardowi::noun', 0.7467872500419617),
#  ('ne#Haileyowi::noun', 0.7432042956352234),
#  ('ne#Burdowskiego::noun', 0.7410663962364197)]

# %%
wv_from_text.most_similar(positive=['ne#Trybunał_Konstytucyjny::noun'])
# Out:
# [('ne#Sąd_Najwyższy::noun', 0.9170992374420166),
#  ('ne#Naczelny_Sąd_Administracyjny::noun', 0.8836387395858765),
#  ('ne#Trybunał::noun', 0.8749106526374817),
#  ('ne#Europejski_Trybunał_Sprawiedliwości::noun', 0.8486111760139465),
#  ('ne#Trybunał_Kon::noun', 0.8447885513305664),
#  ('ne#Trybunał_Sprawiedliwości::noun', 0.8291670083999634),
#  ('ne#Krajowa_Rada_Sądownictwa::noun', 0.8236898183822632),
#  ('ne#Trybunału_Konstytucyjnego::noun', 0.8211962580680847),
#  ('ne#Sąd_Konstytucyjny::noun', 0.8205336332321167),
#  ('ne#Europejski_Trybunał_Praw_Człowieka::noun', 0.8189906477928162)]

# %%
wv_from_text.most_similar(positive=['kodeks_cywilny::noun'])
# Out:
# [('ne#Kodeksu_cywilnego::noun', 0.9549584984779358),
#  ('ne#Kodeks_Cywilny::noun', 0.8858152627944946),
#  ('ne#Kodeksie_cywilnym::noun', 0.860245943069458),
#  ('ne#Kodeksie_Cywilnym::noun', 0.8507591485977173),
#  ('ne#kodeksu_cywilnego::noun', 0.8474100232124329),
#  ('kodeks_handlowy::noun', 0.8371900320053101),
#  ('kodeks_pracy::noun', 0.837181806564331),
#  ('ne#Kodeksu_Cywilnego::noun', 0.8325188159942627),
#  ('ne#Kodeksu_postępowania_cywilnego::noun', 0.8184878826141357),
#  ('ne#Kodeks_cywilny::noun', 0.8184183835983276)]

# %%
wv_from_text.most_similar(positive=['kpk::noun'])
# Out:
# [('ne#Kodeksu_postępowania_karnego::noun', 0.8661121129989624),
#  ('kpk::adj', 0.8617310523986816),
#  ('kpc::noun', 0.8536956310272217),
#  ('kk::noun', 0.8311821818351746),
#  ('ppsa::noun', 0.8293906450271606),
#  ('ne#KPC::noun', 0.8081650733947754),
#  ('ne#Kodeksu_postępowania_w_sprawach_o_wykroczenia::noun',
#   0.8027453422546387),
#  ('ne#Kpa::noun', 0.7999781370162964),
#  ('kpow::noun', 0.7975167632102966),
#  ('1kpk::adj', 0.7967638373374939)]

# %%
wv_from_text.most_similar(positive=['ne#Sąd_Rejonowy::noun'])
# Out:
# [('ne#Sąd_Wojewódzki::noun', 0.8868764638900757),
#  ('ne#Sąd_Okręgowy::noun', 0.8695836067199707),
#  ('ne#Sąd_Rejonowy_w_Częstochowie::noun', 0.85019850730896),
#  ('ne#Sądu_Rejonowego::noun', 0.8484529256820679),
#  ('ne#Sąd_Rejonowy_w_Lublinie::noun', 0.8462358713150024),
#  ('ne#Prokuratura_Rejonowa::noun', 0.842261016368866),
#  ('ne#Sąd_Rejonowy_dla_Krakowa::noun', 0.8409225344657898),
#  ('ne#Rejonowy::noun', 0.8374640941619873),
#  ('ne#Sąd_Rejonowy_w_Gdańsku::noun', 0.8360278606414795),
#  ('ne#Sąd_Rejonowy_w_Białymstoku::noun', 0.8345733880996704)]

# %%
wv_from_text.most_similar(positive=['szkoda::noun'])
# Out:
# [('wyrządzić::verb', 0.7564010620117188),
#  ('Krzywda::noun', 0.7515829205513),
#  ('strata::noun', 0.7275083661079407),
#  ('nieszczęście::noun', 0.7267874479293823),
#  ('obawiać_się::verb', 0.7152366638183594),
#  ('pożytek::noun', 0.7028508186340332),
#  ('żałować::verb', 0.7016452550888062),
#  ('korzyść::noun', 0.6929349303245544),
#  ('skutek::noun', 0.6910550594329834),
#  ('przypuszczać::verb', 0.6901097297668457)]

# %%
wv_from_text.most_similar(positive=['wypadek::noun'])
# Out:
# [('przypadek::noun', 0.8552337288856506),
#  ('okoliczność::noun', 0.8122090697288513),
#  ('skutek::noun', 0.7716399431228638),
#  ('sytuacja::noun', 0.761337161064148),
#  ('zdarzenie::noun', 0.7389098405838013),
#  ('zapewne::qub', 0.7356680631637573),
#  ('przyczyna::noun', 0.7271959185600281),
#  ('wydarzenie::noun', 0.7241967916488647),
#  ('prawdopodobnie::adv', 0.7228392958641052),
#  ('jednakże::qub', 0.7212308049201965)]

# %%
wv_from_text.most_similar(positive=['kolizja::noun'])
# Out:
# [('kolizja_drogowa::noun', 0.8072466850280762),
#  ('kolizj::noun', 0.7978355288505554),
#  ('wypadek_drogowy::noun', 0.7862640619277954),
#  ('zderzenie::noun', 0.7812461256980896),
#  ('zderzenie_czołowe::noun', 0.7508682608604431),
#  ('kraksa::noun', 0.7374911308288574),
#  ('stłuczka::noun', 0.7361663579940796),
#  ('drogowyc::noun', 0.7356817126274109),
#  ('zdarzać::noun', 0.7281510829925537),
#  ('awaria::noun', 0.7276296615600586)]

# %%
wv_from_text.most_similar(positive=['szkoda_majątkowa::noun'])
# Out:
# [('wyrządzić::noun', 0.8379963636398315),
#  ('damnum::noun', 0.7640699148178101),
#  ('wyrządzo::noun', 0.7530648708343506),
#  ('delikt::noun', 0.7494425773620605),
#  ('zagarnięcie_mienia::noun', 0.746197521686554),
#  ('uszczupleń::noun', 0.7421874403953552),
#  ('odszkodowawczy::adj', 0.7415471076965332),
#  ('odpowiedzialność_odszkodowawcza::noun', 0.731763482093811),
#  ('niemajątkowy::adj', 0.7278211116790771),
#  ('emergens::noun', 0.7269477844238281)]

# %%
wv_from_text.most_similar(positive=['nieszczęście::noun'])
# Out:
# [('niebezpieczeństwo::noun', 0.7715556621551514),
#  ('klęska::noun', 0.7639138102531433),
#  ('zguba::noun', 0.7612302303314209),
#  ('zgryzota::noun', 0.759131908416748),
#  ('Krzywda::noun', 0.7577098608016968),
#  ('strapienie::noun', 0.7569986581802368),
#  ('niedola::noun', 0.7511890530586243),
#  ('los::noun', 0.7467725276947021),
#  ('nieszczęśliwy::adj', 0.743039608001709),
#  ('utrapienie::noun', 0.7418053150177002)]

# %%
wv_from_text.most_similar(positive=['rozwód::noun'])
# Out:
# [('małżeństwo::noun', 0.8230218887329102),
#  ('rozwodowy::adj', 0.8101382255554199),
#  ('rozwiedziony::adj', 0.7854081392288208),
#  ('rozwieść_się::verb', 0.7774686217308044),
#  ('rozwieść::verb', 0.773705005645752),
#  ('małżeńśtwa::noun', 0.7710735201835632),
#  ('rozwiedzeni::noun', 0.7502769231796265),
#  ('konkubinat::noun', 0.7491039037704468),
#  ('rozwódka::noun', 0.7407065033912659),
#  ('ne#Katarzyną_Aragońską::noun', 0.7383209466934204)]

# %%
wv_from_text.most_similar(positive=['ne#Wysoki_Sąd::noun', 'konstytucja::noun'], negative=['kpc::noun'], topn=5)
# Out:
# [('ne#Zuokas::noun', 0.6455651521682739),
#  ('ne#Gauck::noun', 0.6336802840232849),
#  ('ne#Wilsonie::noun', 0.6304869651794434),
#  ('ne#Huntera_Peala::noun', 0.6301225423812866),
#  ('ne#Lech_W_ałęsa::noun', 0.6286807060241699)]

# %%
wv_from_text.most_similar(positive=['pasażer::noun','kobieta::noun'], negative=['mężczyzna::noun'], topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('podróżny::noun', 0.8415741324424744),
#  ('współpasażer::noun', 0.7920056581497192),
#  ('podróżujący::noun', 0.7550978064537048),
#  ('kierowca::noun', 0.7446858286857605),
#  ('bagażowy::noun', 0.7316379547119141)]

# %%
wv_from_text.most_similar(positive=['samochód::noun','rzeka::noun'], negative=['droga::noun'], topn=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('motorówka::noun', 0.7439929246902466),
#  ('jezioro::noun', 0.7345261573791504),
#  ('Łódź::noun', 0.7254728674888611),
#  ('ne#Helensburgha::noun', 0.7246426343917847),
#  ('ne#East_River::noun', 0.7199319005012512)]

# %%
from sklearn import manifold

# %%
highlited_vectors = [
#     wv_from_text['szkoda::noun'],
#     wv_from_text['strata::noun'],
    wv_from_text['uszczerbek::noun'],
    wv_from_text['szkoda_majątkowa::noun'],
#     wv_from_text['uszczerbek::noun'] + wv_from_text['na::prep'] +wv_from_text['zdrowie::noun'],
#     wv_from_text['krzywde::noun'],
    wv_from_text['niesprawiedliwość::noun'],
    wv_from_text['nieszczęście::noun']
]

# %%
keys = list(wv_from_text.vocab.keys())

# %%
random_keys = np.random.choice(keys[:800000],  1000)

# %%
random_vectors = list(map(lambda key:  wv_from_text[key], random_keys))

# %%
all_vectors = highlited_vectors + random_vectors

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit_transform(all_vectors)

# %%
import matplotlib.pyplot as plt

# %%
h = len(highlited_vectors)

# %%
plt.figure(figsize=(18,9))
plt.scatter(X_embedded[h+1:, 0], X_embedded[h+1:, 1])
plt.scatter(X_embedded[:h, 0], X_embedded[:h, 1], c='r')
plt.show()
