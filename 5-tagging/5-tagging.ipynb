# %% [markdown]
# # Morphosyntactic tagging

# %% [markdown]
# ## Solution of https://github.com/apohllo/nlp/blob/master/5-tagging.md

# %%
import requests
from os import listdir
from os.path import isfile, join

# %%
url = "http://localhost:9200"

# %%
all_bills = []
def load_bills(directory_path: str):
    files = [file for file in listdir(directory_path) if isfile(join(directory_path, file))]
    for file in files:
        with open(f"{directory_path}/{file}") as input_file:
            corpus =input_file.read()
            r = requests.post(url, corpus.encode("utf-8"))
            all_bills.append(r.text)

# %%
load_bills('./data/')

# %%
import pickle
def serialize(name, dictionary):
    with open(name, 'wb') as handle:
        pickle.dump(dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)
def deserialize(name):
    with open(name, 'rb') as handle:
        return pickle.load(handle)

# %%
serialize('all_bills_tag.pickle', all_bills)

# %%
print(all_bills[0])
# Out:
# Dz	none
# 	dziennik	brev:pun	disamb
# .	none
# 	.	interp	disamb
# U	none
# 	ustawa	brev:pun	disamb
# .	none
# 	.	interp	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# 2003	space
# 	2003	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	newline
# 	numer	brev:npun	disamb
# 228	space
# 	228	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 2259	space
# 	2259	num:pl:nom:m3:rec	disamb
#
# U	none
# 	u	prep:gen	disamb
# S	space
# 	Solidarność	brev:npun	disamb
# T	space
# 	tesla	brev:npun	disamb
# A	space
# 	a	conj	disamb
# W	space
# 	w	prep:loc:nwok	disamb
# A	space
# 	A	subst:sg:loc:n	disamb
#
# z	none
# 	z	prep:gen:nwok	disamb
# dnia	space
# 	dzień	subst:sg:gen:m3	disamb
# 12	space
# 	12	adj:sg:gen:m3:pos	disamb
# grudnia	space
# 	grudzień	subst:sg:gen:m3	disamb
# 2003	space
# 	2003	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# o	none
# 	o	prep:loc	disamb
# zmianie	space
# 	zmiana	subst:sg:loc:f	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# -	space
# 	-	interp	disamb
# Prawo	space
# 	prawo	subst:sg:nom:n	disamb
# wodne	space
# 	wodny	adj:sg:nom:n:pos	disamb
#
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# W	none
# 	w	prep:loc:nwok	disamb
# ustawie	space
# 	ustawa	subst:sg:loc:f	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# dnia	space
# 	dzień	subst:sg:gen:m3	disamb
# 18	space
# 	18	adj:sg:gen:m3:pos	disamb
# lipca	space
# 	lipiec	subst:sg:gen:m3	disamb
# 2001	space
# 	2001	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# -	newline
# 	-	interp	disamb
# Prawo	space
# 	prawo	subst:sg:nom:n	disamb
# wodne	space
# 	wodny	adj:sg:nom:n:pos	disamb
# (	space
# 	(	interp	disamb
# Dz	none
# 	dziennik	brev:pun	disamb
# .	none
# 	.	interp	disamb
# U	none
# 	ustawa	brev:pun	disamb
# .	none
# 	.	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 115	space
# 	115	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1229	space
# 	1229	adj:sg:nom:f:pos	disamb
# ,	none
# 	,	interp	disamb
# z	space
# 	z	prep:gen:nwok	disamb
#
# późn	none
# 	późniejszy	brev:pun	disamb
# .	none
# 	.	interp	disamb
# zm	space
# 	zmarł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# )	none
# 	)	interp	disamb
# [	none
# 	[	interp	disamb
# 1	none
# 	1	adj:sg:nom:n:pos	disamb
# ]	none
# 	]	interp	disamb
# wprowadza	space
# 	wprowadzać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# następujące	space
# 	następujący	adj:pl:acc:f:pos	disamb
# zmiany	space
# 	zmiana	subst:pl:acc:f	disamb
# :	none
# 	:	interp	disamb
#
# 1	none
# 	1	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45	space
# 	45	adj:sg:loc:m3:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 3	space
# 	3	adj:sg:loc:m3:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 5	space
# 	5	adj:sg:loc:m3:pos	disamb
# kropkę	space
# 	kropka	subst:sg:acc:f	disamb
# na	space
# 	na	prep:loc	disamb
# końcu	space
# 	koniec	subst:sg:loc:m3	disamb
# zastępuje	space
# 	zastępować	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# przecinkiem	space
# 	przecinek	subst:sg:inst:m3	disamb
# i	space
# 	i	conj	disamb
#
# dodaje	none
# 	dodawać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 6	space
# 	6	adj:sg:nom:m3:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# brzmieniu	space
# 	brzmienie	subst:sg:loc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# 6	none
# 	6	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# zróżnicowanie	space
# 	zróżnicowanie	subst:sg:acc:n	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# czasie	space
# 	czas	subst:sg:loc:m3	disamb
# warunków	space
# 	warunek	subst:pl:gen:m3	disamb
# ,	none
# 	,	interp	disamb
# jakie	space
# 	jaki	adj:pl:acc:m3:pos	disamb
# należy	space
# 	należeć	fin:sg:ter:imperf	disamb
# spełnić	space
# 	spełnić	inf:perf	disamb
# przy	space
# 	przy	prep:loc	disamb
# wprowadzaniu	space
# 	wprowadzać	ger:sg:loc:n:imperf:aff	disamb
#
# do	none
# 	do	prep:gen	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# ścieków	space
# 	ściek	subst:pl:gen:m3	disamb
# zawierających	space
# 	zawierać	pact:pl:gen:m3:imperf:aff	disamb
# substancje	space
# 	substancja	subst:pl:acc:f	disamb
# szczególnie	space
# 	szczególnie	adv:pos	disamb
# szkodliwe	space
# 	szkodliwy	adj:pl:acc:f:pos	disamb
# dla	space
# 	dla	prep:gen	disamb
#
# środowiska	none
# 	środowisko	subst:sg:gen:n	disamb
# wodnego	space
# 	wodny	adj:sg:gen:n:pos	disamb
# ,	none
# 	,	interp	disamb
# powodujące	space
# 	powodować	pact:pl:acc:n:imperf:aff	disamb
# zanieczyszczenie	space
# 	zanieczyszczenie	subst:sg:acc:n	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# ,	none
# 	,	interp	disamb
# które	space
# 	który	adj:sg:nom:n:pos	disamb
# powinno	space
# 	powinien	winien:sg:n:imperf	disamb
# być	space
# 	być	inf:imperf	disamb
#
# eliminowane	none
# 	eliminować	ppas:sg:nom:n:imperf:aff	disamb
# (	space
# 	(	interp	disamb
# wykaz	none
# 	wykaz	subst:sg:nom:m3	disamb
# I	space
# 	I	adj:sg:nom:m3:pos	disamb
# )	none
# 	)	interp	disamb
# .	none
# 	.	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# po	space
# 	po	prep:loc	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45	space
# 	45	adj:sg:loc:m3:pos	disamb
# dodaje	space
# 	dodawać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45a	space
# 	45a	subst:sg:nom:n	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# brzmieniu	space
# 	brzmienie	subst:sg:loc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45a	space
# 	45a	subst:sg:nom:n	disamb
# .	none
# 	.	interp	disamb
#
# Warunki	newline
# 	warunek	subst:pl:acc:m3	disamb
# ,	none
# 	,	interp	disamb
# jakie	space
# 	jaki	adj:pl:acc:m3:pos	disamb
# należy	space
# 	należeć	fin:sg:ter:imperf	disamb
# spełnić	space
# 	spełnić	inf:perf	disamb
# przy	space
# 	przy	prep:loc	disamb
# wprowadzaniu	space
# 	wprowadzać	ger:sg:loc:n:imperf:aff	disamb
# do	space
# 	do	prep:gen	disamb
# urządzeń	space
# 	urządzenie	subst:pl:gen:n	disamb
#
# kanalizacyjnych	none
# 	kanalizacyjny	adj:pl:gen:m3:pos	disamb
# ścieków	space
# 	ściek	subst:pl:gen:m3	disamb
# zawierających	space
# 	zawierać	pact:pl:gen:m3:imperf:aff	disamb
# substancje	space
# 	substancja	subst:pl:acc:f	disamb
# szczególnie	space
# 	szczególnie	adv:pos	disamb
#
# szkodliwe	none
# 	szkodliwy	adj:pl:acc:f:pos	disamb
# dla	space
# 	dla	prep:gen	disamb
# środowiska	space
# 	środowisko	subst:sg:gen:n	disamb
# wodnego	space
# 	wodny	adj:sg:gen:n:pos	disamb
# określone	space
# 	określić	ppas:sg:nom:n:perf:aff	disamb
# na	space
# 	na	prep:loc	disamb
# podstawie	space
# 	podstawa	subst:sg:loc:f	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45	space
# 	45	adj:sg:gen:m3:pos	disamb
#
# ust	none
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# określają	space
# 	określać	fin:pl:ter:imperf	disamb
# przepisy	space
# 	przepis	subst:pl:acc:m3	disamb
# o	space
# 	o	prep:loc	disamb
# zbiorowym	space
# 	zbiorowy	adj:sg:loc:n:pos	disamb
# zaopatrzeniu	space
# 	zaopatrzenie	subst:sg:loc:n	disamb
# w	space
# 	w	prep:acc:nwok	disamb
# wodę	space
# 	woda	subst:sg:acc:f	disamb
#
# i	none
# 	i	conj	disamb
# zbiorowym	space
# 	zbiorowy	adj:sg:loc:n:pos	disamb
# odprowadzaniu	space
# 	odprowadzać	ger:sg:loc:n:imperf:aff	disamb
# ścieków	space
# 	ściek	subst:pl:gen:m3	disamb
# .	none
# 	.	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 3	none
# 	3	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 49	space
# 	49	adj:sg:gen:m3:pos	disamb
# otrzymuje	space
# 	otrzymywać	fin:sg:ter:imperf	disamb
# brzmienie	space
# 	brzmienie	subst:sg:acc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 49	space
# 	49	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# 1	newline
# 	1	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Badania	newline
# 	badanie	subst:pl:nom:n	disamb
# i	space
# 	i	conj	disamb
# ocenę	space
# 	ocena	subst:sg:acc:f	disamb
# jakości	space
# 	jakość	subst:pl:gen:f	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# zakresie	space
# 	zakres	subst:sg:loc:m3	disamb
#
# elementów	none
# 	element	subst:pl:gen:m3	disamb
# fizycznych	space
# 	fizyczny	adj:pl:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# chemicznych	space
# 	chemiczny	adj:pl:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# biologicznych	space
# 	biologiczny	adj:pl:gen:m3:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
#
# podziemnych	none
# 	podziemny	adj:pl:gen:m3:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# zakresie	space
# 	zakres	subst:sg:loc:m3	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
# fizycznych	space
# 	fizyczny	adj:pl:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# chemicznych	space
# 	chemiczny	adj:pl:gen:m3:pos	disamb
# dokonuje	space
# 	dokonywać	fin:sg:ter:imperf	disamb
#
# się	none
# 	się	qub	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ramach	space
# 	ramy	subst:pl:loc:n	disamb
# państwowego	space
# 	państwowy	adj:sg:gen:m3:pos	disamb
# monitoringu	space
# 	monitoring	subst:sg:gen:m3	disamb
# środowiska	space
# 	środowisko	subst:sg:gen:n	disamb
# .	none
# 	.	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Wojewódzki	newline
# 	wojewódzki	adj:sg:nom:m1:pos	disamb
# inspektor	space
# 	inspektor	subst:sg:nom:m1	disamb
# ochrony	space
# 	ochrona	subst:sg:gen:f	disamb
# środowiska	space
# 	środowisko	subst:sg:gen:n	disamb
# wykonuje	space
# 	wykonywać	fin:sg:ter:imperf	disamb
# badania	space
# 	badanie	subst:pl:acc:n	disamb
# oraz	space
# 	oraz	conj	disamb
# ocenę	space
# 	ocena	subst:sg:acc:f	disamb
#
# jakości	none
# 	jakość	subst:pl:gen:f	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# i	space
# 	i	conj	disamb
# podziemnych	space
# 	podziemny	adj:pl:gen:f:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# zakresie	space
# 	zakres	subst:sg:loc:m3	disamb
# określonym	space
# 	określić	ppas:sg:loc:m3:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
#
# ust	none
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# 3	none
# 	3	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Gdy	newline
# 	gdy	adv	disamb
# jest	space
# 	być	fin:sg:ter:imperf	disamb
# to	space
# 	to	subst:sg:nom:n	disamb
# uzasadnione	space
# 	uzasadnić	ppas:sg:nom:n:perf:aff	disamb
# specyfiką	space
# 	specyfika	subst:sg:inst:f	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# ,	none
# 	,	interp	disamb
# obowiązki	space
# 	obowiązek	subst:pl:nom:m3	disamb
# dotyczące	space
# 	dotyczyć	pact:pl:nom:m3:imperf:aff	disamb
#
# prowadzenia	none
# 	prowadzić	ger:sg:gen:n:imperf:aff	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# oraz	space
# 	oraz	conj	disamb
# przeprowadzenia	space
# 	przeprowadzić	ger:sg:gen:n:perf:aff	disamb
# oceny	space
# 	ocena	subst:sg:gen:f	disamb
# jakości	space
# 	jakość	subst:sg:gen:f	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
#
# powierzchniowych	none
# 	powierzchniowy	adj:pl:gen:n:pos	disamb
# i	space
# 	i	conj	disamb
# podziemnych	space
# 	podziemny	adj:pl:gen:n:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# zakresie	space
# 	zakres	subst:sg:loc:m3	disamb
# określonym	space
# 	określić	ppas:sg:loc:m3:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
#
# wykonuje	none
# 	wykonywać	fin:sg:ter:imperf	disamb
# Główny	space
# 	główny	adj:sg:nom:m1:pos	disamb
# Inspektor	space
# 	inspektor	subst:sg:nom:m1	disamb
# Ochrony	space
# 	ochrona	subst:sg:gen:f	disamb
# Środowiska	space
# 	środowisko	subst:sg:gen:n	disamb
# .	none
# 	.	interp	disamb
#
# 4	none
# 	4	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Minister	newline
# 	minister	subst:sg:nom:m1	disamb
# właściwy	space
# 	właściwy	adj:sg:nom:m1:pos	disamb
# do	space
# 	do	prep:gen	disamb
# spraw	space
# 	sprawa	subst:pl:gen:f	disamb
# gospodarki	space
# 	gospodarka	subst:sg:gen:f	disamb
# wodnej	space
# 	wodny	adj:sg:gen:f:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# porozumieniu	space
# 	porozumienie	subst:sg:loc:n	disamb
# z	space
# 	z	prep:gen:nwok	disamb
#
# ministrem	none
# 	minister	subst:sg:inst:m1	disamb
# właściwym	space
# 	właściwy	adj:sg:inst:m1:pos	disamb
# do	space
# 	do	prep:gen	disamb
# spraw	space
# 	sprawa	subst:pl:gen:f	disamb
# środowiska	space
# 	środowisko	subst:sg:gen:n	disamb
# określi	space
# 	określić	fin:sg:ter:perf	disamb
# ,	none
# 	,	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# drodze	space
# 	droga	subst:sg:loc:f	disamb
#
# rozporządzenia	none
# 	rozporządzenie	subst:pl:nom:n	disamb
# ,	none
# 	,	interp	disamb
# sposób	space
# 	sposób	subst:sg:nom:m3	disamb
# oceny	space
# 	ocena	subst:sg:gen:f	disamb
# stanu	space
# 	stan	subst:sg:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# i	space
# 	i	conj	disamb
#
# podziemnych	none
# 	podziemny	adj:pl:gen:f:pos	disamb
# ,	none
# 	,	interp	disamb
# uwzględniający	space
# 	uwzględniać	pact:sg:nom:m1:imperf:aff	disamb
# :	none
# 	:	interp	disamb
#
# 1	none
# 	1	adj:sg:nom:f:pos	disamb
# )	none
# 	)	interp	disamb
# klasyfikację	space
# 	klasyfikacja	subst:sg:acc:f	disamb
# :	none
# 	:	interp	disamb
#
# a	none
# 	a	subst:sg:nom:n	disamb
# )	none
# 	)	interp	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
# fizycznych	space
# 	fizyczny	adj:pl:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# chemicznych	space
# 	chemiczny	adj:pl:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# biologicznych	space
# 	biologiczny	adj:pl:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
#
# hydrologicznych	none
# 	hydrologiczny	adj:pl:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# morfologicznych	space
# 	morfologiczny	adj:pl:gen:m3:pos	disamb
# uwzględniającą	space
# 	uwzględniać	pact:sg:inst:f:imperf:aff	disamb
# warunki	space
# 	warunek	subst:pl:acc:m3	disamb
#
# referencyjne	none
# 	referencyjny	adj:pl:nom:m3:pos	disamb
# różnych	space
# 	różny	adj:pl:gen:m3:pos	disamb
# typów	space
# 	typ	subst:pl:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# ,	none
# 	,	interp	disamb
#
# b	none
# 	b	subst:sg:nom:n	disamb
# )	none
# 	)	interp	disamb
# ekologicznego	space
# 	ekologiczny	adj:sg:gen:m3:pos	disamb
# stanu	space
# 	stan	subst:sg:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# uwzględniającą	space
# 	uwzględniać	pact:sg:inst:f:imperf:aff	disamb
#
# klasyfikację	none
# 	klasyfikacja	subst:sg:acc:f	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# których	space
# 	który	adj:pl:loc:m3:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
#
# lit	none
# 	litera	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# a	newline
# 	a	conj	disamb
# ,	none
# 	,	interp	disamb
#
# c	none
# 	c	subst:sg:nom:n	disamb
# )	none
# 	)	interp	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
# fizycznych	none
# 	fizyczny	adj:pl:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# chemicznych	space
# 	chemiczny	adj:pl:gen:m3:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# zasobów	space
# 	zasób	subst:pl:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
#
# odniesieniu	none
# 	odniesienie	subst:sg:loc:n	disamb
# do	space
# 	do	prep:gen	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# podziemnych	space
# 	podziemny	adj:pl:gen:f:pos	disamb
# ,	none
# 	,	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:m3:pos	disamb
# )	none
# 	)	interp	disamb
# sposób	space
# 	sposób	subst:sg:nom:m3	disamb
# interpretacji	space
# 	interpretacja	subst:sg:gen:f	disamb
# wyników	space
# 	wynik	subst:pl:gen:m3	disamb
# ,	none
# 	,	interp	disamb
#
# 3	none
# 	3	adj:sg:nom:m3:pos	disamb
# )	none
# 	)	interp	disamb
# sposób	space
# 	sposób	subst:sg:nom:m3	disamb
# prezentacji	space
# 	prezentacja	subst:sg:gen:f	disamb
# jakości	space
# 	jakość	subst:sg:gen:f	disamb
# poszczególnych	space
# 	poszczególny	adj:pl:gen:m3:pos	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
# klasyfikacji	space
# 	klasyfikacja	subst:sg:gen:f	disamb
#
# wód	none
# 	woda	subst:pl:gen:f	disamb
# oraz	space
# 	oraz	conj	disamb
# oceny	space
# 	ocena	subst:pl:nom:f	disamb
# stanu	space
# 	stan	subst:sg:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# ,	none
# 	,	interp	disamb
#
# 4	none
# 	4	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# częstotliwość	space
# 	częstotliwość	subst:sg:acc:f	disamb
# dokonywania	space
# 	dokonywać	ger:sg:gen:n:imperf:aff	disamb
# ocen	space
# 	ocena	subst:pl:gen:f	disamb
# jakości	space
# 	jakość	subst:sg:gen:f	disamb
# poszczególnych	space
# 	poszczególny	adj:pl:gen:m3:pos	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
#
# oraz	none
# 	oraz	conj	disamb
# stanu	space
# 	stan	subst:sg:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# .	none
# 	.	interp	disamb
#
# 5	none
# 	5	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Minister	newline
# 	minister	subst:sg:nom:m1	disamb
# ,	none
# 	,	interp	disamb
# wydając	space
# 	wydawać	pcon:imperf	disamb
# rozporządzenie	space
# 	rozporządzenie	subst:sg:acc:n	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# którym	space
# 	który	adj:sg:loc:n:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 4	space
# 	4	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# będzie	space
# 	być	bedzie:sg:ter:imperf	disamb
#
# się	none
# 	się	qub	disamb
# kierować	space
# 	kierować	inf:imperf	disamb
# istniejącym	space
# 	istnieć	pact:sg:inst:m3:imperf:aff	disamb
# stanem	space
# 	stan	subst:sg:inst:m3	disamb
# rozpoznania	space
# 	rozpoznać	ger:sg:gen:n:perf:aff	disamb
# procesów	space
# 	proces	subst:pl:gen:m3	disamb
# zachodzących	space
# 	zachodzić	pact:pl:gen:m3:imperf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
#
# środowisku	none
# 	środowisko	subst:sg:dat:n	disamb
# wodnym	space
# 	wodny	adj:sg:loc:n:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# dostępnymi	space
# 	dostępny	adj:pl:inst:m3:pos	disamb
# wynikami	space
# 	wynik	subst:pl:inst:m3	disamb
# pomiarów	space
# 	pomiar	subst:pl:gen:m3	disamb
# i	space
# 	i	conj	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# .	none
# 	.	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 4	none
# 	4	num:pl:nom:m3:congr	disamb
# )	none
# 	)	interp	disamb
# po	space
# 	po	prep:loc	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 49	space
# 	49	adj:sg:loc:m3:pos	disamb
# dodaje	space
# 	dodawać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 49a	space
# 	49a	subst:sg:nom:n	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# brzmieniu	space
# 	brzmienie	subst:sg:loc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 49a	space
# 	49a	subst:sg:nom:n	disamb
# .	none
# 	.	interp	disamb
#
# 1	newline
# 	1	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Minister	newline
# 	minister	subst:sg:nom:m1	disamb
# właściwy	space
# 	właściwy	adj:sg:nom:m1:pos	disamb
# do	space
# 	do	prep:gen	disamb
# spraw	space
# 	sprawa	subst:pl:gen:f	disamb
# gospodarki	space
# 	gospodarka	subst:sg:gen:f	disamb
# wodnej	space
# 	wodny	adj:sg:gen:f:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# porozumieniu	space
# 	porozumienie	subst:sg:loc:n	disamb
#
# z	none
# 	z	prep:inst:nwok	disamb
# ministrem	space
# 	minister	subst:sg:inst:m1	disamb
# właściwym	space
# 	właściwy	adj:sg:inst:m1:pos	disamb
# do	space
# 	do	prep:gen	disamb
# spraw	space
# 	sprawa	subst:pl:gen:f	disamb
# środowiska	space
# 	środowisko	subst:sg:gen:n	disamb
# określi	space
# 	określić	fin:sg:ter:perf	disamb
# ,	none
# 	,	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# drodze	space
# 	droga	subst:sg:loc:f	disamb
#
# rozporządzenia	none
# 	rozporządzenie	subst:pl:nom:n	disamb
# ,	none
# 	,	interp	disamb
# sposób	space
# 	sposób	subst:sg:nom:m3	disamb
# prowadzenia	space
# 	prowadzić	ger:sg:gen:n:imperf:aff	disamb
# monitoringu	space
# 	monitoring	subst:sg:gen:m3	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
#
# powierzchniowych	none
# 	powierzchniowy	adj:pl:gen:n:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# podziemnych	space
# 	podziemny	adj:pl:gen:n:pos	disamb
# ,	none
# 	,	interp	disamb
# uwzględniający	space
# 	uwzględniać	pact:sg:nom:m1:imperf:aff	disamb
# :	none
# 	:	interp	disamb
#
# 1	none
# 	1	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# kryteria	space
# 	kryterium	subst:pl:acc:n	disamb
# wyznaczania	space
# 	wyznaczać	ger:sg:gen:n:imperf:aff	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# i	space
# 	i	conj	disamb
# podziemnych	space
# 	podziemny	adj:pl:gen:f:pos	disamb
# objętych	space
# 	objąć	ppas:pl:gen:f:perf:aff	disamb
#
# monitoringiem	none
# 	monitoring	subst:sg:inst:m3	disamb
# ,	none
# 	,	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# kryteria	space
# 	kryterium	subst:pl:acc:n	disamb
# wyznaczania	space
# 	wyznaczać	ger:sg:gen:n:imperf:aff	disamb
# punktów	space
# 	punkt	subst:pl:gen:m3	disamb
# pomiarów	space
# 	pomiar	subst:pl:gen:m3	disamb
# i	space
# 	i	conj	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# ,	none
# 	,	interp	disamb
#
# 3	none
# 	3	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# zakres	space
# 	zakres	subst:sg:nom:m3	disamb
# i	space
# 	i	conj	disamb
# częstotliwość	space
# 	częstotliwość	subst:sg:nom:f	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# poszczególnych	space
# 	poszczególny	adj:pl:gen:m3:pos	disamb
# elementów	space
# 	element	subst:pl:gen:m3	disamb
# ,	none
# 	,	interp	disamb
#
# 4	none
# 	4	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# metodyki	space
# 	metodyka	subst:pl:nom:f	disamb
# referencyjne	space
# 	referencyjny	adj:pl:nom:f:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# warunki	space
# 	warunki	subst:pl:nom:n	disamb
# zapewnienia	space
# 	zapewnienie	subst:sg:gen:n	disamb
# jakości	space
# 	jakość	subst:sg:gen:f	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# .	none
# 	.	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Minister	newline
# 	minister	subst:sg:nom:m1	disamb
# ,	none
# 	,	interp	disamb
# wydając	space
# 	wydawać	pcon:imperf	disamb
# rozporządzenie	space
# 	rozporządzenie	subst:sg:acc:n	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# którym	space
# 	który	adj:sg:loc:n:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# będzie	space
# 	być	bedzie:sg:ter:imperf	disamb
#
# się	none
# 	się	qub	disamb
# kierować	space
# 	kierować	inf:imperf	disamb
# analizą	space
# 	analiza	subst:sg:inst:f	disamb
# dotychczas	space
# 	dotychczas	adv	disamb
# funkcjonującego	space
# 	funkcjonować	pact:sg:gen:m3:imperf:aff	disamb
# systemu	space
# 	system	subst:sg:gen:m3	disamb
# monitoringu	space
# 	monitoring	subst:sg:gen:m3	disamb
#
# wód	none
# 	woda	subst:pl:gen:f	disamb
# powierzchniowych	space
# 	powierzchniowy	adj:pl:gen:f:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# podziemnych	space
# 	podziemny	adj:pl:gen:f:pos	disamb
# .	none
# 	.	interp	disamb
#
# W	newline
# 	w	prep:loc:nwok	disamb
# zakresie	space
# 	zakres	subst:sg:loc:m3	disamb
# metodyk	space
# 	metodyka	subst:pl:gen:f	disamb
#
# referencyjnych	none
# 	referencyjny	adj:pl:gen:n:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# warunków	space
# 	warunki	subst:pl:gen:n	disamb
# jakości	space
# 	jakość	subst:sg:gen:f	disamb
# badań	space
# 	badanie	subst:pl:gen:n	disamb
# tych	space
# 	ten	adj:pl:gen:f:pos	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# minister	space
# 	minister	subst:sg:nom:m1	disamb
# będzie	space
# 	być	bedzie:sg:ter:imperf	disamb
#
# się	none
# 	się	qub	disamb
# kierować	space
# 	kierować	inf:imperf	disamb
# obowiązującymi	space
# 	obowiązujący	adj:pl:inst:m3:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# tym	space
# 	ten	adj:sg:loc:m3:pos	disamb
# zakresie	space
# 	zakres	subst:sg:loc:m3	disamb
# przepisami	space
# 	przepis	subst:pl:inst:m3	disamb
# prawa	space
# 	prawo	subst:sg:gen:n	disamb
# Unii	space
# 	unia	subst:sg:gen:f	disamb
#
# Europejskiej	none
# 	europejski	adj:sg:gen:f:pos	disamb
# .	none
# 	.	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 5	none
# 	5	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 164	space
# 	164	adj:sg:nom:m3:pos	disamb
# otrzymuje	space
# 	otrzymywać	fin:sg:ter:imperf	disamb
# brzmienie	space
# 	brzmienie	subst:sg:acc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 164	space
# 	164	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# 1	newline
# 	1	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Spółki	newline
# 	spółka	subst:pl:nom:f	disamb
# wodne	space
# 	wodny	adj:pl:nom:f:pos	disamb
# ,	none
# 	,	interp	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# zastrzeżeniem	space
# 	zastrzeżenie	subst:sg:inst:n	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 2	space
# 	2	adj:sg:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# oraz	space
# 	oraz	conj	disamb
# związki	space
# 	związek	subst:pl:nom:m3	disamb
# wałowe	space
# 	wałowy	adj:pl:nom:m3:pos	disamb
#
# są	none
# 	być	fin:pl:ter:imperf	disamb
# formami	space
# 	forma	subst:pl:inst:f	disamb
# organizacyjnymi	space
# 	organizacyjny	adj:pl:inst:f:pos	disamb
# ,	none
# 	,	interp	disamb
# które	space
# 	który	adj:pl:nom:f:pos	disamb
# nie	space
# 	nie	qub	disamb
# działają	space
# 	działać	fin:pl:ter:imperf	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# celu	space
# 	cel	subst:sg:loc:m3	disamb
# osiągnięcia	space
# 	osiągnąć	ger:sg:gen:n:perf:aff	disamb
#
# zysku	none
# 	zysk	subst:sg:gen:m3	disamb
# ,	none
# 	,	interp	disamb
# zrzeszają	space
# 	zrzeszać	fin:pl:ter:imperf	disamb
# osoby	space
# 	osoba	subst:pl:nom:f	disamb
# fizyczne	space
# 	fizyczny	adj:pl:nom:f:pos	disamb
# lub	space
# 	lub	conj	disamb
# prawne	space
# 	prawny	adj:pl:nom:f:pos	disamb
# i	space
# 	i	conj	disamb
# mają	space
# 	mieć	fin:pl:ter:imperf	disamb
# na	space
# 	na	prep:loc	disamb
# celu	space
# 	cel	subst:sg:loc:m3	disamb
#
# zaspokajanie	none
# 	zaspokajać	ger:sg:nom:n:imperf:aff	disamb
# wskazanych	space
# 	wskazać	ppas:pl:gen:f:perf:aff	disamb
# ustawą	space
# 	ustawa	subst:sg:inst:f	disamb
# potrzeb	space
# 	potrzeba	subst:pl:gen:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# dziedzinie	space
# 	dziedzina	subst:sg:loc:f	disamb
# gospodarowania	space
# 	gospodarowanie	subst:sg:gen:n	disamb
#
# wodami	none
# 	woda	subst:pl:inst:f	disamb
# .	none
# 	.	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Spółki	newline
# 	spółka	subst:pl:nom:f	disamb
# wodne	space
# 	wodny	adj:pl:nom:f:pos	disamb
# ,	none
# 	,	interp	disamb
# zapewniając	space
# 	zapewniać	pcon:imperf	disamb
# zaspokojenie	space
# 	zaspokojenie	subst:sg:acc:n	disamb
# potrzeb	space
# 	potrzeba	subst:pl:gen:f	disamb
# zrzeszonych	space
# 	zrzeszyć	ppas:pl:gen:f:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# nich	space
# 	on	ppron3:pl:loc:f:ter:akc:praep	disamb
#
# osób	none
# 	osoba	subst:pl:gen:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# dziedzinie	space
# 	dziedzina	subst:sg:loc:f	disamb
# gospodarowania	space
# 	gospodarować	ger:sg:gen:n:imperf:aff	disamb
# wodami	space
# 	woda	subst:pl:inst:f	disamb
# ,	none
# 	,	interp	disamb
# mogą	space
# 	móc	fin:pl:ter:imperf	disamb
# podejmować	space
# 	podejmować	inf:imperf	disamb
# prowadzenie	space
# 	prowadzenie	subst:sg:acc:n	disamb
#
# działalności	none
# 	działalność	subst:sg:gen:f	disamb
# umożliwiającej	space
# 	umożliwiać	pact:sg:gen:f:imperf:aff	disamb
# osiągnięcie	space
# 	osiągnąć	ger:sg:acc:n:perf:aff	disamb
# zysku	space
# 	zysk	subst:sg:gen:m3	disamb
# netto	space
# 	netto	subst:sg:gen:n	disamb
# .	none
# 	.	interp	disamb
#
# Osiągnięty	newline
# 	osiągnąć	ppas:sg:nom:m3:perf:aff	disamb
# zysk	space
# 	zysk	subst:sg:nom:m3	disamb
#
# netto	none
# 	netto	subst:sg:nom:n	disamb
# przeznacza	space
# 	przeznaczać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# wyłącznie	space
# 	wyłącznie	qub	disamb
# na	space
# 	na	prep:acc	disamb
# cele	space
# 	cel	subst:pl:acc:m3	disamb
# statutowe	space
# 	statutowy	adj:pl:acc:m3:pos	disamb
# spółki	space
# 	spółka	subst:sg:gen:f	disamb
# wodnej	space
# 	wodny	adj:sg:gen:f:pos	disamb
# .	none
# 	.	interp	disamb
#
# 3	none
# 	3	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Spółki	newline
# 	spółka	subst:pl:nom:f	disamb
# wodne	space
# 	wodny	adj:pl:nom:f:pos	disamb
# mogą	space
# 	móc	fin:pl:ter:imperf	disamb
# być	space
# 	być	inf:imperf	disamb
# tworzone	space
# 	tworzyć	ppas:pl:nom:f:imperf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# szczególności	space
# 	szczególność	subst:sg:loc:f	disamb
# do	space
# 	do	prep:gen	disamb
# wykonywania	space
# 	wykonywać	ger:sg:gen:n:imperf:aff	disamb
# ,	none
# 	,	interp	disamb
#
# utrzymywania	none
# 	utrzymywać	ger:sg:gen:n:imperf:aff	disamb
# oraz	space
# 	oraz	conj	disamb
# eksploatacji	space
# 	eksploatacja	subst:sg:gen:f	disamb
# urządzeń	space
# 	urządzenie	subst:pl:gen:n	disamb
# służących	space
# 	służyć	pact:pl:gen:n:imperf:aff	disamb
# do	space
# 	do	prep:gen	disamb
# :	none
# 	:	interp	disamb
#
# 1	none
# 	1	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# zapewnienia	space
# 	zapewnienie	subst:sg:gen:n	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# dla	space
# 	dla	prep:gen	disamb
# ludności	space
# 	ludność	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# tym	space
# 	to	subst:sg:loc:n	disamb
# uzdatniania	space
# 	uzdatniać	ger:sg:gen:n:imperf:aff	disamb
# i	space
# 	i	conj	disamb
# dostarczania	space
# 	dostarczać	ger:sg:gen:n:imperf:aff	disamb
#
# wody	none
# 	woda	subst:pl:nom:f	disamb
# ,	none
# 	,	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# ochrony	space
# 	ochrona	subst:sg:gen:f	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# przed	space
# 	przed	prep:inst:nwok	disamb
# zanieczyszczeniem	space
# 	zanieczyszczenie	subst:sg:inst:n	disamb
# ,	none
# 	,	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# tym	space
# 	ten	adj:sg:loc:n:pos	disamb
# odprowadzania	space
# 	odprowadzać	ger:sg:gen:n:imperf:aff	disamb
# i	space
# 	i	conj	disamb
#
# oczyszczania	none
# 	oczyszczać	ger:sg:gen:n:imperf:aff	disamb
# ścieków	space
# 	ściek	subst:pl:gen:m3	disamb
# ,	none
# 	,	interp	disamb
#
# 3	none
# 	3	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# ochrony	space
# 	ochrona	subst:sg:gen:f	disamb
# przed	space
# 	przed	prep:inst:nwok	disamb
# powodzią	space
# 	powódź	subst:sg:inst:f	disamb
# ,	none
# 	,	interp	disamb
#
# 4	none
# 	4	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# melioracji	space
# 	melioracja	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# prowadzenia	space
# 	prowadzić	ger:sg:gen:n:imperf:aff	disamb
# racjonalnej	space
# 	racjonalny	adj:sg:gen:f:pos	disamb
# gospodarki	space
# 	gospodarka	subst:sg:gen:f	disamb
# na	space
# 	na	prep:acc	disamb
#
# terenach	none
# 	teren	subst:pl:loc:m3	disamb
# zmeliorowanych	space
# 	zmeliorować	ppas:pl:loc:m3:perf:aff	disamb
# ,	none
# 	,	interp	disamb
#
# 5	none
# 	5	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# wykorzystywania	space
# 	wykorzystywać	ger:sg:gen:n:imperf:aff	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# do	space
# 	do	prep:gen	disamb
# celów	space
# 	cel	subst:pl:gen:m3	disamb
# przeciwpożarowych	space
# 	przeciwpożarowy	adj:pl:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
#
# 6	none
# 	6	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# utrzymywania	space
# 	utrzymywać	ger:sg:gen:n:imperf:aff	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# .	none
# 	.	interp	disamb
#
# 4	none
# 	4	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Do	newline
# 	do	prep:gen	disamb
# prowadzenia	space
# 	prowadzić	ger:sg:gen:n:imperf:aff	disamb
# działalności	space
# 	działalność	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 3	space
# 	3	adj:sg:loc:m3:pos	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# i	space
# 	i	conj	disamb
# 2	space
# 	2	adj:sg:nom:m3:pos	disamb
# ,	none
# 	,	interp	disamb
#
# stosuje	none
# 	stosować	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# odpowiednio	space
# 	odpowiednio	adv:pos	disamb
# przepisy	space
# 	przepis	subst:pl:acc:m3	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 8	space
# 	8	adj:sg:gen:m3:pos	disamb
# -	none
# 	-	interp	disamb
# 10	none
# 	10	adj:sg:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# 12	space
# 	12	adj:sg:gen:m3:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# przepisy	space
# 	przepis	subst:pl:acc:m3	disamb
# wydane	space
# 	wydać	ppas:pl:acc:m3:perf:aff	disamb
#
# na	none
# 	na	prep:loc	disamb
# podstawie	space
# 	podstawa	subst:sg:loc:f	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 11	space
# 	11	adj:sg:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# 13	space
# 	13	adj:sg:gen:m3:pos	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# dnia	space
# 	dzień	subst:sg:gen:m3	disamb
# 7	space
# 	7	adj:sg:gen:m3:pos	disamb
# czerwca	space
# 	czerwiec	subst:sg:gen:m3	disamb
# 2001	space
# 	2001	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
# o	space
# 	o	prep:acc	disamb
#
# zbiorowym	none
# 	zbiorowy	adj:sg:loc:n:pos	disamb
# zaopatrzeniu	space
# 	zaopatrzenie	subst:sg:loc:n	disamb
# w	space
# 	w	prep:acc:nwok	disamb
# wodę	space
# 	woda	subst:sg:acc:f	disamb
# i	space
# 	i	conj	disamb
# zbiorowym	space
# 	zbiorowy	adj:sg:loc:n:pos	disamb
# odprowadzaniu	space
# 	odprowadzać	ger:sg:loc:n:imperf:aff	disamb
# ścieków	space
# 	ściek	subst:pl:gen:m3	disamb
# .	none
# 	.	interp	disamb
#
# 5	none
# 	5	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Z	newline
# 	z	prep:inst:nwok	disamb
# zastrzeżeniem	space
# 	zastrzeżenie	subst:sg:inst:n	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 6	space
# 	6	adj:sg:nom:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# spółki	space
# 	spółka	subst:pl:nom:f	disamb
# wodne	space
# 	wodny	adj:pl:nom:f:pos	disamb
# mogą	space
# 	móc	fin:pl:ter:imperf	disamb
# korzystać	space
# 	korzystać	inf:imperf	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# pomocy	space
# 	pomoc	subst:sg:gen:f	disamb
#
# państwa	none
# 	państwo	subst:sg:gen:n	disamb
# oraz	space
# 	oraz	conj	disamb
# jednostek	space
# 	jednostka	subst:pl:gen:f	disamb
# samorządu	space
# 	samorząd	subst:sg:gen:m3	disamb
# terytorialnego	space
# 	terytorialny	adj:sg:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# formie	space
# 	forma	subst:sg:loc:f	disamb
# dotacji	space
# 	dotacja	subst:sg:gen:f	disamb
#
# podmiotowych	none
# 	podmiotowy	adj:pl:gen:f:pos	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# budżetu	space
# 	budżet	subst:sg:gen:m3	disamb
# państwa	space
# 	państwo	subst:sg:gen:n	disamb
# oraz	space
# 	oraz	conj	disamb
# dotacji	space
# 	dotacja	subst:sg:gen:f	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# budżetu	space
# 	budżet	subst:sg:gen:m3	disamb
# jednostki	space
# 	jednostka	subst:sg:gen:f	disamb
#
# samorządu	none
# 	samorząd	subst:sg:gen:m3	disamb
# terytorialnego	space
# 	terytorialny	adj:sg:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# przeznaczonych	space
# 	przeznaczyć	ppas:pl:gen:m3:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# szczególności	space
# 	szczególność	subst:sg:loc:f	disamb
# na	space
# 	na	prep:acc	disamb
# bieżące	space
# 	bieżeć	pact:pl:acc:f:imperf:aff	disamb
#
# utrzymanie	none
# 	utrzymać	ger:sg:nom:n:perf:aff	disamb
# wód	space
# 	woda	subst:pl:gen:f	disamb
# i	space
# 	i	conj	disamb
# urządzeń	space
# 	urządzenie	subst:pl:gen:n	disamb
# wodnych	space
# 	wodny	adj:pl:gen:n:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# realizację	space
# 	realizacja	subst:sg:acc:f	disamb
# inwestycji	space
# 	inwestycja	subst:pl:gen:f	disamb
# ,	none
# 	,	interp	disamb
#
# udzielanych	none
# 	udzielać	ppas:pl:gen:m3:imperf:aff	disamb
# zgodnie	space
# 	zgodnie	adv:pos	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# przepisami	space
# 	przepis	subst:pl:inst:m3	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# o	space
# 	o	prep:loc	disamb
# finansach	space
# 	finanse	subst:pl:loc:n	disamb
# publicznych	space
# 	publiczny	adj:pl:loc:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# 6	none
# 	6	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Przepisów	newline
# 	przepis	subst:pl:gen:m3	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 5	space
# 	5	adj:sg:nom:m3:pos	disamb
# nie	space
# 	nie	qub	disamb
# stosuje	space
# 	stosować	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# do	space
# 	do	prep:gen	disamb
# spółki	space
# 	spółka	subst:sg:gen:f	disamb
# wodnej	space
# 	wodny	adj:sg:gen:f:pos	disamb
# prowadzącej	space
# 	prowadzić	pact:sg:gen:f:imperf:aff	disamb
#
# działalność	none
# 	działalność	subst:sg:nom:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 2	space
# 	2	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# polegającą	space
# 	polegać	pact:sg:inst:f:imperf:aff	disamb
# na	space
# 	na	prep:loc	disamb
# uzdatnianiu	space
# 	uzdatniać	ger:sg:loc:n:imperf:aff	disamb
# i	space
# 	i	conj	disamb
#
# dostarczaniu	none
# 	dostarczać	ger:sg:loc:n:imperf:aff	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# dla	space
# 	dla	prep:gen	disamb
# ludności	space
# 	ludność	subst:sg:gen:f	disamb
# oraz	space
# 	oraz	conj	disamb
# na	space
# 	na	prep:loc	disamb
# odprowadzaniu	space
# 	odprowadzać	ger:sg:loc:n:imperf:aff	disamb
# i	space
# 	i	conj	disamb
# oczyszczaniu	space
# 	oczyszczać	ger:sg:loc:n:imperf:aff	disamb
#
# ścieków	none
# 	ściek	subst:pl:gen:m3	disamb
# .	none
# 	.	interp	disamb
#
# 7	none
# 	7	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Udzielenie	newline
# 	udzielić	ger:sg:nom:n:perf:aff	disamb
# spółce	space
# 	spółka	subst:sg:dat:f	disamb
# wodnej	space
# 	wodny	adj:sg:dat:f:pos	disamb
# ,	none
# 	,	interp	disamb
# wykonującej	space
# 	wykonywać	pact:sg:dat:f:imperf:aff	disamb
# urządzenia	space
# 	urządzić	ger:sg:gen:n:perf:aff	disamb
# melioracji	space
# 	melioracja	subst:sg:gen:f	disamb
#
# wodnych	none
# 	wodny	adj:pl:gen:f:pos	disamb
# ,	none
# 	,	interp	disamb
# pomocy	space
# 	pomoc	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 5	space
# 	5	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# może	space
# 	móc	fin:sg:ter:imperf	disamb
# nastąpić	space
# 	nastąpić	inf:perf	disamb
# wówczas	space
# 	wówczas	adv	disamb
# ,	none
# 	,	interp	disamb
# gdy	space
# 	gdy	adv	disamb
#
# obszar	none
# 	obszar	subst:sg:nom:m3	disamb
# przewidziany	space
# 	przewidzieć	ppas:sg:nom:m3:perf:aff	disamb
# do	space
# 	do	prep:gen	disamb
# melioracji	space
# 	melioracja	subst:sg:gen:f	disamb
# stanowi	space
# 	stanowić	fin:sg:ter:imperf	disamb
# zwarty	space
# 	zwarty	adj:sg:acc:m3:pos	disamb
# kompleks	space
# 	kompleks	subst:sg:acc:m3	disamb
# ,	none
# 	,	interp	disamb
# zasięg	space
# 	zasięg	subst:sg:acc:m3	disamb
#
# oraz	none
# 	oraz	conj	disamb
# projekt	space
# 	projekt	subst:sg:nom:m3	disamb
# techniczny	space
# 	techniczny	adj:sg:nom:m3:pos	disamb
# melioracji	space
# 	melioracja	subst:sg:gen:f	disamb
# zostały	space
# 	zostać	praet:pl:m3:perf	disamb
# uzgodnione	space
# 	uzgodnić	ppas:pl:nom:m3:perf:aff	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# wojewodą	space
# 	wojewoda	subst:sg:inst:m1	disamb
# ,	none
# 	,	interp	disamb
# a	space
# 	a	conj	disamb
#
# udział	none
# 	udział	subst:sg:acc:m3	disamb
# własny	space
# 	własny	adj:sg:acc:m3:pos	disamb
# członków	space
# 	członek	subst:pl:gen:m1	disamb
# spółki	space
# 	spółka	subst:sg:gen:f	disamb
# odpowiada	space
# 	odpowiadać	fin:sg:ter:imperf	disamb
# co	space
# 	co	prep:acc	disamb
# najmniej	space
# 	mało	adv:sup	disamb
# kwocie	space
# 	kwota	subst:sg:dat:f	disamb
#
# wyliczonej	none
# 	wyliczyć	ppas:sg:gen:f:perf:aff	disamb
# zgodnie	space
# 	zgodnie	adv:pos	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 74	space
# 	74	adj:sg:inst:m3:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# przepisami	space
# 	przepis	subst:pl:inst:m3	disamb
# wydanymi	space
# 	wydać	ppas:pl:inst:m3:perf:aff	disamb
# na	space
# 	na	prep:loc	disamb
# podstawie	space
# 	podstawa	subst:sg:loc:f	disamb
#
# art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 78	space
# 	78	adj:sg:gen:m3:pos	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# 8	none
# 	8	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Spółki	newline
# 	spółka	subst:pl:nom:f	disamb
# wodne	space
# 	wodny	adj:pl:nom:f:pos	disamb
# mogą	space
# 	móc	fin:pl:ter:imperf	disamb
# łączyć	space
# 	łączyć	inf:imperf	disamb
# się	space
# 	się	qub	disamb
# w	space
# 	w	prep:acc:nwok	disamb
# związki	space
# 	związek	subst:pl:acc:m3	disamb
# spółek	space
# 	spółka	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
# .	none
# 	.	interp	disamb
#
# 9	none
# 	9	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Do	newline
# 	do	prep:gen	disamb
# związków	space
# 	związek	subst:pl:gen:m3	disamb
# spółek	space
# 	spółka	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
# stosuje	space
# 	stosować	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# odpowiednio	space
# 	odpowiednio	adv:pos	disamb
# przepisy	space
# 	przepis	subst:pl:acc:m3	disamb
#
# dotyczące	none
# 	dotyczyć	pact:pl:nom:f:imperf:aff	disamb
# spółek	space
# 	spółka	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
# ,	none
# 	,	interp	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# tym	space
# 	to	subst:sg:inst:n	disamb
# że	space
# 	że	comp	disamb
# prawa	space
# 	prawo	subst:pl:nom:n	disamb
# i	space
# 	i	conj	disamb
# obowiązki	space
# 	obowiązek	subst:pl:nom:m3	disamb
# przysługujące	space
# 	przysługiwać	pact:pl:nom:m3:imperf:aff	disamb
#
# wobec	none
# 	wobec	prep:gen	disamb
# spółek	space
# 	spółka	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
# staroście	space
# 	starosta	subst:sg:dat:m1	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# stosunku	space
# 	stosunek	subst:sg:loc:m3	disamb
# do	space
# 	do	prep:gen	disamb
# związków	space
# 	związek	subst:pl:gen:m3	disamb
# spółek	space
# 	spółka	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
#
# wykonuje	none
# 	wykonywać	fin:sg:ter:imperf	disamb
# marszałek	space
# 	marszałek	subst:sg:nom:m1	disamb
# województwa	space
# 	województwo	subst:sg:gen:n	disamb
# .	none
# 	.	interp	disamb
#
# 10	none
# 	10	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Związki	newline
# 	związek	subst:pl:nom:m3	disamb
# wałowe	space
# 	wałowy	adj:pl:nom:m3:pos	disamb
# mogą	space
# 	móc	fin:pl:ter:imperf	disamb
# być	space
# 	być	inf:imperf	disamb
# tworzone	space
# 	tworzyć	ppas:pl:nom:m3:imperf:aff	disamb
# do	space
# 	do	prep:gen	disamb
# wykonywania	space
# 	wykonywać	ger:sg:gen:n:imperf:aff	disamb
# i	space
# 	i	conj	disamb
# utrzymywania	space
# 	utrzymywać	ger:sg:gen:n:imperf:aff	disamb
#
# wałów	none
# 	wał	subst:pl:gen:m3	disamb
# przeciwpowodziowych	space
# 	przeciwpowodziowy	adj:pl:gen:m3:pos	disamb
# wraz	space
# 	wraz	adv	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# urządzeniami	space
# 	urządzenie	subst:pl:inst:n	disamb
# wodnymi	space
# 	wodny	adj:pl:inst:n:pos	disamb
# stanowiącymi	space
# 	stanowić	pact:pl:inst:n:imperf:aff	disamb
#
# ich	none
# 	on	ppron3:pl:gen:m1:ter:akc:npraep	disamb
# wyposażenie	space
# 	wyposażenie	subst:sg:nom:n	disamb
# .	none
# 	.	interp	disamb
#
# 11	none
# 	11	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Przepisy	newline
# 	przepis	subst:pl:acc:m3	disamb
# dotyczące	space
# 	dotyczyć	pact:pl:acc:m3:imperf:aff	disamb
# spółek	space
# 	spółka	subst:pl:gen:f	disamb
# wodnych	space
# 	wodny	adj:pl:gen:f:pos	disamb
# i	space
# 	i	conj	disamb
# ich	space
# 	on	ppron3:pl:gen:m3:ter:akc:npraep	disamb
# związków	space
# 	związek	subst:pl:gen:m3	disamb
# stosuje	space
# 	stosować	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
#
# odpowiednio	none
# 	odpowiednio	adv:pos	disamb
# do	space
# 	do	prep:gen	disamb
# związków	space
# 	związek	subst:pl:gen:m3	disamb
# wałowych	space
# 	wałowy	adj:pl:gen:m3:pos	disamb
# .	none
# 	.	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 6	none
# 	6	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 166	space
# 	166	adj:sg:loc:m3:pos	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# po	space
# 	po	prep:loc	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 3	space
# 	3	adj:sg:loc:m3:pos	disamb
# dodaje	space
# 	dodawać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 3a	space
# 	3a	subst:sg:nom:n	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# brzmieniu	space
# 	brzmienie	subst:sg:loc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# 3a	none
# 	3a	subst:sg:nom:n	disamb
# )	none
# 	)	interp	disamb
# zasady	space
# 	zasada	subst:pl:acc:f	disamb
# ustalania	space
# 	ustalać	ger:sg:gen:n:imperf:aff	disamb
# należności	space
# 	należność	subst:sg:gen:f	disamb
# za	space
# 	za	prep:acc	disamb
# dostarczanie	space
# 	dostarczać	ger:sg:acc:n:imperf:aff	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# oraz	space
# 	oraz	conj	disamb
# odprowadzanie	space
# 	odprowadzać	ger:sg:acc:n:imperf:aff	disamb
#
# i	none
# 	i	conj	disamb
# oczyszczanie	space
# 	oczyszczać	ger:sg:nom:n:imperf:aff	disamb
# ścieków	space
# 	ściek	subst:pl:gen:m3	disamb
# ,	none
# 	,	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# przypadku	space
# 	przypadek	subst:sg:loc:m3	disamb
# prowadzenia	space
# 	prowadzić	ger:sg:gen:n:imperf:aff	disamb
# działalności	space
# 	działalność	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
#
# mowa	none
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 164	space
# 	164	adj:sg:loc:m3:pos	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 2	space
# 	2	adj:sg:nom:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 7	none
# 	7	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 170	space
# 	170	adj:sg:loc:m3:pos	disamb
# uchyla	space
# 	uchylać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 4	space
# 	4	adj:sg:nom:m3:pos	disamb
# ;	none
# 	;	interp	disamb
#
# 8	none
# 	8	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 171	space
# 	171	adj:sg:loc:m3:pos	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# otrzymuje	space
# 	otrzymywać	fin:sg:ter:imperf	disamb
# brzmienie	space
# 	brzmienie	subst:sg:acc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# 1	none
# 	1	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Jeżeli	newline
# 	jeżeli	comp	disamb
# osoby	space
# 	osoba	subst:pl:nom:f	disamb
# fizyczne	space
# 	fizyczny	adj:pl:nom:f:pos	disamb
# lub	space
# 	lub	conj	disamb
# osoby	space
# 	osoba	subst:pl:nom:f	disamb
# prawne	space
# 	prawny	adj:pl:nom:f:pos	disamb
# niebędące	space
# 	być	pact:pl:nom:f:imperf:neg	disamb
# członkami	space
# 	członek	subst:pl:inst:m3	disamb
# spółki	space
# 	spółka	subst:sg:gen:f	disamb
#
# wodnej	none
# 	wodny	adj:sg:gen:f:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# jednostki	space
# 	jednostka	subst:pl:nom:f	disamb
# organizacyjne	space
# 	organizacyjny	adj:pl:nom:f:pos	disamb
# nieposiadające	space
# 	nieposiadający	adj:pl:nom:f:pos	disamb
# osobowości	space
# 	osobowość	subst:sg:gen:f	disamb
# prawnej	space
# 	prawny	adj:sg:gen:f:pos	disamb
#
# odnoszą	none
# 	odnosić	fin:pl:ter:imperf	disamb
# korzyści	space
# 	korzyść	subst:pl:nom:f	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# urządzeń	space
# 	urządzenie	subst:pl:gen:n	disamb
# spółki	space
# 	spółka	subst:sg:gen:f	disamb
# lub	space
# 	lub	conj	disamb
# przyczyniają	space
# 	przyczyniać	fin:pl:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# do	space
# 	do	prep:gen	disamb
#
# zanieczyszczenia	none
# 	zanieczyścić	ger:sg:gen:n:perf:aff	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# dla	space
# 	dla	prep:gen	disamb
# której	space
# 	który	adj:sg:gen:f:pos	disamb
# ochrony	space
# 	ochrona	subst:sg:gen:f	disamb
# spółka	space
# 	spółka	subst:sg:nom:f	disamb
# została	space
# 	zostać	praet:sg:f:perf	disamb
# utworzona	space
# 	utworzyć	ppas:sg:nom:f:perf:aff	disamb
# ,	none
# 	,	interp	disamb
#
# obowiązane	none
# 	obowiązany	adj:pl:nom:f:pos	disamb
# są	space
# 	być	fin:pl:ter:imperf	disamb
# do	space
# 	do	prep:gen	disamb
# ponoszenia	space
# 	ponosić	ger:sg:gen:n:imperf:aff	disamb
# świadczeń	space
# 	świadczenie	subst:pl:gen:n	disamb
# na	space
# 	na	prep:acc	disamb
# rzecz	space
# 	rzecz	subst:sg:acc:f	disamb
# spółki	space
# 	spółka	subst:sg:gen:f	disamb
# .	none
# 	.	interp	disamb
# "	none
# 	"	interp	disamb
# ;	none
# 	;	interp	disamb
#
# 9	none
# 	9	adj:sg:nom:n:pos	disamb
# )	none
# 	)	interp	disamb
# po	space
# 	po	prep:loc	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 171	space
# 	171	adj:sg:loc:m3:pos	disamb
# dodaje	space
# 	dodawać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 171a	space
# 	171a	subst:sg:nom:n	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# brzmieniu	space
# 	brzmienie	subst:sg:loc:n	disamb
# :	none
# 	:	interp	disamb
#
# "	none
# 	"	interp	disamb
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 171a	space
# 	171a	subst:sg:nom:n	disamb
# .	none
# 	.	interp	disamb
#
# Dostarczanie	newline
# 	dostarczać	ger:sg:nom:n:imperf:aff	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# oraz	space
# 	oraz	conj	disamb
# odprowadzanie	space
# 	odprowadzać	ger:sg:nom:n:imperf:aff	disamb
# i	space
# 	i	conj	disamb
# ...
# 	5	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 43	space
# 	43	adj:sg:nom:f:pos	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 72	space
# 	72	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# 747	none
# 	747	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 100	space
# 	100	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1085	space
# 	1085	adj:sg:gen:m3:pos	disamb
# i	space
# 	i	conj	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 125	space
# 	125	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1368	space
# 	1368	adj:sg:nom:f:pos	disamb
# )	none
# 	)	interp	disamb
# strefy	space
# 	strefa	subst:pl:nom:f	disamb
# ochronne	space
# 	ochronny	adj:pl:nom:f:pos	disamb
# ujęć	space
# 	ujęcie	subst:pl:gen:n	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# stają	space
# 	stawać	fin:pl:ter:imperf	disamb
#
# się	none
# 	się	qub	disamb
# strefami	space
# 	strefa	subst:pl:inst:f	disamb
# ochronnymi	space
# 	ochronny	adj:pl:inst:f:pos	disamb
# ujęć	space
# 	ujęcie	subst:pl:gen:n	disamb
# wody	space
# 	woda	subst:sg:gen:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# rozumieniu	space
# 	rozumienie	subst:sg:loc:n	disamb
# przepisów	space
# 	przepis	subst:pl:gen:m3	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
#
# mowa	none
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# .	none
# 	.	interp	disamb
#
# Postępowania	newline
# 	postępowanie	subst:pl:nom:n	disamb
# administracyjne	space
# 	administracyjny	adj:pl:nom:n:pos	disamb
# wszczęte	space
# 	wszcząć	ppas:pl:nom:n:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# przedmiocie	space
# 	przedmiot	subst:sg:loc:m3	disamb
# stref	space
# 	strefa	subst:pl:gen:f	disamb
# ochronnych	space
# 	ochronny	adj:pl:gen:n:pos	disamb
# ujęć	space
# 	ujęcie	subst:pl:gen:n	disamb
#
# wody	none
# 	woda	subst:pl:acc:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# których	space
# 	który	adj:pl:loc:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# umarza	space
# 	umarzać	fin:sg:ter:imperf	disamb
# się	space
# 	się	qub	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# dniem	space
# 	dzień	subst:sg:inst:m3	disamb
# wejścia	space
# 	wejść	ger:sg:gen:n:perf:aff	disamb
# w	space
# 	w	prep:acc:nwok	disamb
# życie	space
# 	życie	subst:sg:acc:n	disamb
# niniejszej	space
# 	niniejszy	adj:sg:gen:f:pos	disamb
#
# ustawy	none
# 	ustawa	subst:sg:gen:f	disamb
# .	none
# 	.	interp	disamb
#
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 3	space
# 	3	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# Dotychczasowe	none
# 	dotychczasowy	adj:pl:acc:m3:pos	disamb
# przepisy	space
# 	przepis	subst:pl:nom:m3	disamb
# wykonawcze	space
# 	wykonawczy	adj:pl:nom:m3:pos	disamb
# wydane	space
# 	wydać	ppas:pl:nom:m3:perf:aff	disamb
# na	space
# 	na	prep:loc	disamb
# podstawie	space
# 	podstawa	subst:sg:loc:f	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45	space
# 	45	adj:sg:gen:m3:pos	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# i	space
# 	i	conj	disamb
# 3	space
# 	3	adj:sg:nom:m3:pos	disamb
#
# ustawy	none
# 	ustawa	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# zachowują	space
# 	zachowywać	fin:pl:ter:imperf	disamb
# moc	space
# 	moc	subst:sg:acc:f	disamb
# do	space
# 	do	prep:gen	disamb
# czasu	space
# 	czas	subst:sg:gen:m3	disamb
# wydania	space
# 	wydać	ger:sg:gen:n:perf:aff	disamb
# nowych	space
# 	nowy	adj:pl:gen:m3:pos	disamb
# przepisów	space
# 	przepis	subst:pl:gen:m3	disamb
#
# wykonawczych	none
# 	wykonawczy	adj:pl:gen:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# jednak	space
# 	jednak	conj	disamb
# nie	space
# 	nie	qub	disamb
# dłużej	space
# 	długo	adv:com	disamb
# niż	space
# 	niż	conj	disamb
# przez	space
# 	przez	prep:acc:nwok	disamb
# okres	space
# 	okres	subst:sg:acc:m3	disamb
# 6	space
# 	6	num:pl:gen:m3:congr	disamb
# miesięcy	space
# 	miesiąc	subst:pl:gen:m3	disamb
# od	space
# 	od	prep:gen:nwok	disamb
# dnia	space
# 	dzień	subst:sg:gen:m3	disamb
# wejścia	space
# 	wejść	ger:sg:gen:n:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
#
# życie	none
# 	życie	subst:sg:nom:n	disamb
# niniejszej	space
# 	niniejszy	adj:sg:gen:f:pos	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# .	none
# 	.	interp	disamb
#
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 4	space
# 	4	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# Dotychczasowe	none
# 	dotychczasowy	adj:pl:acc:m3:pos	disamb
# przepisy	space
# 	przepis	subst:pl:acc:m3	disamb
# wykonawcze	space
# 	wykonawczy	adj:pl:acc:m3:pos	disamb
# wydane	space
# 	wydać	ppas:pl:nom:m3:perf:aff	disamb
# na	space
# 	na	prep:loc	disamb
# podstawie	space
# 	podstawa	subst:sg:loc:f	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 45	space
# 	45	adj:sg:gen:m3:pos	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 2	space
# 	2	adj:sg:nom:m3:pos	disamb
# i	space
# 	i	conj	disamb
#
# ust	none
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 2	space
# 	2	adj:sg:nom:m3:pos	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:loc	disamb
# której	space
# 	który	adj:sg:loc:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# zachowują	space
# 	zachowywać	fin:pl:ter:imperf	disamb
# moc	space
# 	moc	subst:sg:acc:f	disamb
# do	space
# 	do	prep:gen	disamb
# czasu	space
# 	czas	subst:sg:gen:m3	disamb
# wydania	space
# 	wydać	ger:sg:gen:n:perf:aff	disamb
# nowych	space
# 	nowy	subst:pl:gen:m1	disamb
#
# przepisów	none
# 	przepis	subst:pl:gen:m3	disamb
# wykonawczych	space
# 	wykonawczy	adj:pl:gen:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 5	space
# 	5	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# Dotychczasowe	none
# 	dotychczasowy	adj:pl:acc:m3:pos	disamb
# przepisy	space
# 	przepis	subst:pl:nom:m3	disamb
# wykonawcze	space
# 	wykonawczy	adj:pl:nom:m3:pos	disamb
# wydane	space
# 	wydać	ppas:pl:nom:m3:perf:aff	disamb
# na	space
# 	na	prep:loc	disamb
# podstawie	space
# 	podstawa	subst:sg:loc:f	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 49	space
# 	49	adj:sg:gen:m3:pos	disamb
# ust	space
# 	ustęp	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 4	space
# 	4	adj:sg:nom:m3:pos	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# ,	none
# 	,	interp	disamb
# o	space
# 	o	prep:acc	disamb
#
# której	none
# 	który	adj:sg:gen:f:pos	disamb
# mowa	space
# 	mowa	subst:sg:nom:f	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:loc:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# zachowują	space
# 	zachowywać	fin:pl:ter:imperf	disamb
# moc	space
# 	moc	subst:sg:acc:f	disamb
# do	space
# 	do	prep:gen	disamb
# dnia	space
# 	dzień	subst:sg:gen:m3	disamb
# 1	space
# 	1	adj:sg:gen:m3:pos	disamb
# stycznia	space
# 	styczeń	subst:sg:gen:m3	disamb
# 2005	space
# 	2005	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Art	none
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 6	space
# 	6	adj:sg:nom:m3:pos	disamb
# .	none
# 	.	interp	disamb
#
# Ustawa	none
# 	ustawa	subst:sg:nom:f	disamb
# wchodzi	space
# 	wchodzić	fin:sg:ter:imperf	disamb
# w	space
# 	w	prep:acc:nwok	disamb
# życie	space
# 	życie	subst:sg:acc:n	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# dniem	space
# 	dzień	subst:sg:inst:m3	disamb
# ogłoszenia	space
# 	ogłosić	ger:sg:gen:n:perf:aff	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# mocą	space
# 	moc	subst:sg:inst:f	disamb
# od	space
# 	od	prep:gen:nwok	disamb
# dnia	space
# 	dzień	subst:sg:gen:m3	disamb
# 30	space
# 	30	adj:sg:gen:m3:pos	disamb
# grudnia	space
# 	grudzień	subst:sg:gen:m3	disamb
# 2003	space
# 	2003	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
# ,	none
# 	,	interp	disamb
# z	space
# 	z	prep:gen:nwok	disamb
#
# wyjątkiem	none
# 	wyjątek	subst:sg:inst:m3	disamb
# art	space
# 	artykuł	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1	space
# 	1	adj:sg:nom:m3:pos	disamb
# pkt	space
# 	punkt	brev:npun	disamb
# 3	space
# 	3	adj:sg:nom:m3:pos	disamb
# i	space
# 	i	conj	disamb
# 4	space
# 	4	adj:sg:nom:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# które	space
# 	który	adj:pl:nom:f:pos	disamb
# wchodzą	space
# 	wchodzić	fin:pl:ter:imperf	disamb
# w	space
# 	w	prep:acc:nwok	disamb
# życie	space
# 	życie	subst:sg:acc:n	disamb
# z	space
# 	z	prep:inst:nwok	disamb
# dniem	space
# 	dzień	subst:sg:inst:m3	disamb
# 1	space
# 	1	adj:sg:gen:m3:pos	disamb
# stycznia	space
# 	styczeń	subst:sg:gen:m3	disamb
# 2005	space
# 	2005	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
# _	none
# 	_	interp	disamb
#
# [	none
# 	[	interp	disamb
# 1	none
# 	1	adj:sg:nom:n:pos	disamb
# ]	none
# 	]	interp	disamb
# Zmiany	none
# 	zmiana	subst:pl:nom:f	disamb
# wymienionej	space
# 	wymienić	ppas:sg:gen:f:perf:aff	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# zostały	space
# 	zostać	praet:pl:f:perf	disamb
# ogłoszone	space
# 	ogłosić	ppas:pl:nom:f:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# Dz	space
# 	dziennik	brev:pun	disamb
# .	none
# 	.	interp	disamb
# U	none
# 	ustawa	brev:pun	disamb
# .	none
# 	.	interp	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# 2001	space
# 	2001	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	newline
# 	numer	brev:npun	disamb
# 154	space
# 	154	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	none
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# 1803	none
# 	1803	num:pl:nom:m3:congr	disamb
# ,	none
# 	,	interp	disamb
# z	none
# 	z	prep:gen:nwok	disamb
# 2002	none
# 	2002	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	newline
# 	numer	brev:npun	disamb
# 113	space
# 	113	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 984	space
# 	984	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 130	space
# 	130	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1112	space
# 	1112	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 233	space
# 	233	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1957	none
# 	1957	num:pl:nom:m3:rec	disamb
# i	none
# 	i	conj	disamb
# Nr	none
# 	numer	brev:npun	disamb
#
# 238	none
# 	238	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	none
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 2022	space
# 	2022	adj:sg:gen:m3:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# 2003	space
# 	2003	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	newline
# 	numer	brev:npun	disamb
# 80	space
# 	80	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 717	space
# 	717	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 165	space
# 	165	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1592	space
# 	1592	num:pl:nom:m3:congr	disamb
# i	space
# 	i	conj	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 190	space
# 	190	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# 1865	none
# 	1865	num:pl:nom:m3:rec	disamb
# .	none
# 	.	interp	disamb
#
# [	none
# 	[	interp	disamb
# 2	none
# 	2	adj:sg:nom:n:pos	disamb
# ]	none
# 	]	interp	disamb
# Zmiany	space
# 	zmiana	subst:pl:nom:f	disamb
# tekstu	space
# 	tekst	subst:sg:gen:m3	disamb
# jednolitego	space
# 	jednolity	adj:sg:gen:m3:pos	disamb
# wymienionej	space
# 	wymienić	ppas:sg:gen:f:perf:aff	disamb
# ustawy	space
# 	ustawa	subst:sg:gen:f	disamb
# zostały	space
# 	zostać	praet:pl:f:perf	disamb
# ogłoszone	space
# 	ogłosić	ppas:pl:nom:f:perf:aff	disamb
# w	space
# 	w	prep:loc:nwok	disamb
# Dz	space
# 	dziennik	brev:pun	disamb
# .	none
# 	.	interp	disamb
# U	none
# 	ustawa	brev:pun	disamb
# .	none
# 	.	interp	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# 2001	space
# 	2001	adj:sg:gen:m3:pos	disamb
#
# r	none
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	none
# 	numer	brev:npun	disamb
# 115	none
# 	115	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1229	space
# 	1229	adj:sg:nom:f:pos	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 122	space
# 	122	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1323	space
# 	1323	num:pl:nom:m3:congr	disamb
# i	space
# 	i	conj	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 154	space
# 	154	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1793	space
# 	1793	adj:sg:nom:m3:pos	disamb
# i	space
# 	i	conj	disamb
# 1800	space
# 	1800	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# 2002	space
# 	2002	adj:sg:gen:m3:pos	disamb
# r	none
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	none
# 	numer	brev:npun	disamb
# 25	none
# 	25	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 253	space
# 	253	adj:sg:nom:f:pos	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 74	space
# 	74	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 676	space
# 	676	adj:sg:nom:f:pos	disamb
# i	space
# 	i	conj	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 155	space
# 	155	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1287	space
# 	1287	adj:sg:gen:m3:pos	disamb
# oraz	space
# 	oraz	conj	disamb
# z	space
# 	z	prep:gen:nwok	disamb
# 2003	space
# 	2003	adj:sg:gen:m3:pos	disamb
# r	space
# 	rok	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# Nr	newline
# 	numer	brev:npun	disamb
# 6	space
# 	6	adj:sg:nom:m3:pos	disamb
# ,	none
# 	,	interp	disamb
# poz	none
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
#
# 64	none
# 	64	num:pl:nom:m3:congr	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 49	space
# 	49	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 408	space
# 	408	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 64	space
# 	64	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 592	space
# 	592	num:pl:nom:m3:congr	disamb
# ,	none
# 	,	interp	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 80	space
# 	80	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 721	space
# 	721	num:pl:nom:m3:rec	disamb
# i	space
# 	i	conj	disamb
# Nr	space
# 	numer	brev:npun	disamb
# 122	space
# 	122	num:pl:nom:m3:rec	disamb
# ,	none
# 	,	interp	disamb
# poz	space
# 	pozycja	brev:pun	disamb
# .	none
# 	.	interp	disamb
# 1143	space
# 	1143	adj:sg:nom:f:pos	disamb
# .	none
# 	.	interp	disamb

# %%
big_list = []
for  bill in all_bills:
    big_list.append(parse_bils(bill))

# %%
def parse_bils(corpus):
    lines = corpus.splitlines()
    pairs_list = []
    for i in range(0, len(lines)):
        if len(lines[i].split('\t')) == 2:
            pairs = parse_next_line(lines[i+1])
            pairs_list.append(pairs)
    return pairs_list

# %%
def parse_next_line(line):
    parts = line.split("\t")
    if len(parts) > 2:
        first = parts[1]
        second = parts[2]
        tags = second.split(':')
        if len(tags) > 1:
            return(f'{first}:{tags[0]}')
        return(f'{first}:{second}')

# %%
bigrams = {}

# %%
def bigram_count():
    for element in big_list:
        i = 0
        j = 1
        while i < len(element) and  j<len(element):
            e1 = element[i]
            e2 = element[j]
            if not is_alpha(e1):
                i+=1
                j+=1
                continue
            elif not is_alpha(e2):
                i+=2
                j+=2
                continue
            else:
                bigram = f'{e1.lower()} {e2.lower()}'
                if bigram not in bigrams:
                    bigrams[bigram] = 1
                else:
                    count = bigrams[bigram]
                    count +=1
                    bigrams[bigram] = count
                i+=1
                j+=1

# %%
def is_alpha(word):
    return word.split(":")[0].isalpha()

# %%
bigram_count()

# %%
unigrams = {}

# %%
for bill in big_list:
    for word in bill:
        if is_alpha(word):
            if word not in unigrams:
                unigrams[word.lower()] = 1
            else:
                count = unigrams[word.lower()]
                count +=1
                unigrams[word.lower()] = count

# %%
from llr import llr_2x2
llr_dict = {}
for bigram in bigrams:
    try:
        word1, word2 = bigram.split(' ')
        not_word1_word2 = unigrams[word2] - bigrams[bigram] 
        word1_not_word2 = unigrams[word1] - bigrams[bigram]
        not_word1_not_word2 = sum(bigrams.values()) - word1_not_word2 - not_word1_word2 - bigrams[bigram]
        llr_dict[bigram] = llr_2x2(bigrams[bigram],not_word1_word2, word1_not_word2, not_word1_not_word2 )
    except:
        continue

# %%
sorted_llr = sorted(llr_dict.items(), key=lambda entry: entry[1] , reverse=True)

# %%
sorted_llr[:50]
# Out:
# [('który:adj mowa:subst', 248324.4349527203),
#  ('o:prep który:adj', 163664.93922446412),
#  ('mowa:subst w:prep', 149503.9146878908),
#  ('otrzymywać:fin brzmienie:subst', 111106.1820813932),
#  ('w:prep artykuł:brev', 67791.56558237551),
#  ('dodawać:fin się:qub', 66927.52216122783),
#  ('w:prep ustęp:brev', 56433.33445513528),
#  ('stosować:fin się:qub', 52971.23413636157),
#  ('droga:subst rozporządzenie:subst', 51583.88981686512),
#  ('właściwy:adj do:prep', 47904.17674144334),
#  ('na:prep podstawa:subst', 45476.403285408625),
#  ('do:prep sprawa:subst', 45253.133482930134),
#  ('z:prep dzień:subst', 43200.15806660266),
#  ('określić:ppas w:prep', 43090.76382959541),
#  ('móc:fin być:inf', 41374.2576458441),
#  ('a:conj także:conj', 40332.86446757338),
#  ('zastępować:fin się:qub', 39196.44044670282),
#  ('się:qub wyraz:subst', 33870.96200476226),
#  ('w:prep w:prep', 31862.451481773518),
#  ('w:prep droga:subst', 31360.723432420986),
#  ('od:prep dzień:subst', 29491.490230257157),
#  ('ustawa:subst z:prep', 29220.106358632096),
#  ('co:prep mało:adv', 28964.847641872228),
#  ('w:prep przypadek:subst', 27223.48574812198),
#  ('zwać:ppas daleko:adv', 24499.65875004523),
#  ('jednostka:subst organizacyjny:adj', 23990.963261174853),
#  ('samorząd:subst terytorialny:adj', 23146.20356611727),
#  ('skreślać:fin się:qub', 22066.649683529045),
#  ('skarb:subst państwo:subst', 21817.516399171698),
#  ('produkt:subst leczniczy:adj', 21293.818880989973),
#  ('się:qub odpowiednio:adv', 21032.867890213092),
#  ('być:fin obowiązany:adj', 20748.32396825077),
#  ('niniejszy:adj ustawa:subst', 19891.027486618725),
#  ('papier:subst wartościowy:adj', 19210.88864118583),
#  ('w:prep szczególność:subst', 18188.902275093133),
#  ('zgodnie:adv z:prep', 18186.547231001314),
#  ('dzień:subst wejść:ger', 18055.943553487363),
#  ('w:prep życie:subst', 17699.31119276816),
#  ('i:conj numer:brev', 17508.116936974693),
#  ('unia:subst europejski:adj', 17211.749992206256),
#  ('następujący:adj zmiana:subst', 17174.233371874725),
#  ('chyba:qub że:comp', 16998.753559387158),
#  ('w:prep zakres:subst', 16832.41075737495),
#  ('związany:adj z:prep', 16560.88917422702),
#  ('ubezpieczenie:subst społeczny:adj', 16462.442902202863),
#  ('działalność:subst gospodarczy:adj', 15989.31338647558),
#  ('w:prep brzmienie:subst', 15774.111247767694),
#  ('finanse:subst publiczny:adj', 14629.235164072204),
#  ('z:prep zastrzeżenie:subst', 14329.27882438514),
#  ('straż:subst graniczny:adj', 14154.254218730064)]
